# %%
from vertex import *
from puzzle import *

def verify(a, b):
        match = 0
        for _a, _b in zip(a,b):
            if _a == _b:
                match +=1
        return (9-match)

def insort(h, states, seeds):
    for j in range(1, len(h)):
        key = h[j]
        st_key = states[j]
        se_key = seeds[j]

        i = j - 1
        while i >= 0 and h[i] > key:
            h[i + 1] = h[i]
            states[i + 1] = states[i]
            seeds[i + 1] = seeds[i]
            i -= 1
        h[i + 1] = key
        states[i + 1] = st_key
        seeds[i + 1] = se_key
    return h, states, seeds

def format_state(state):
    result = ''
    for i in range(3):
        result += f'{state[i * 3: (i + 1) * 3]}\n'
    return result

# %%
############################################################################
p = Puzzle()
test = Puzzle()
logs = True

pending = []
checked = []
steps = []

x0 = ['2', '8', '3',
      '1', '6', '4',
      '7', '#', '5']

x1 = ['2', '1', '6',
      '4', '#', '8',
      '7', '5', '3']

t = ['1', '2', '3',
     '8', '#', '4',
     '7', '6', '5']

p.assign_values(x1)
test.assign_values(p.grid_to_array())

r = Vertex()
r.value = p.grid_to_array()
r.seed = 'root'
r.depth = 0
r.score = verify(r.value, t)
current_vertex = r
second_best = None

max_iterations = 7500


print('Searching...')
for i in range(max_iterations):
      #Se verifica que el nodo actual no es el estado terminal
      if verify(current_vertex.value, t)==0:
            print('_______________________________________________')
            print(f'---Terminal---')
            print(f'Depth: {current_vertex.depth}, Score: {current_vertex.score}')
            print(format_state(current_vertex.value))

            #Para calcular el agoritmo que soluciona el puzzle, basta con preguntarle al nodo actual el movimiento que lo produjo (su 'seed')
            #Y repetir el proceso con su nodo padre hasta llegar a la raiz del arbol.
            steps = []
            while(current_vertex.parent):
                  steps.append(current_vertex.seed)
                  current_vertex = current_vertex.parent
            print('---Algorithm---')
            print(f'From: \n{format_state(r.value)}\n')

            #Ya obtenido el conjunto de pasos, solo le damos la vuelta para que estén en el orden para solucionar el puzzle partiendo del nodo raiz
            steps.reverse()
            j = 1
            for s in steps:
                  print(f'{j}. {s}')
                  j+=1
            print('---end---')
            break
      else:
            #Se calculan los estados sucesores (Se expande el vertice actual)
            p.assign_values(current_vertex.value)
            states, seeds = p.create_states()
            childs = []
            if logs:
                  print('_______________________________________________')
                  print(f'----- ST Calculated - Depth: {current_vertex.depth+1} -----')
                  for st, se in zip(states, seeds):
                        print(f'Seed: {se}\n{format_state(st)}')

            # Se verifica si alguno de los estados ya existe en pending o checked y se agregan a la cola de eliminación si es el caso.
            st_to_delete = []
            se_to_delete = []

            for st, se in zip(states, seeds):
                  if st in pending or st in checked:
                        st_to_delete.append(st)
                        se_to_delete.append(se)

            for st, se in zip(st_to_delete, se_to_delete):
                  states.remove(st)
                  seeds.remove(se)

            if len(states)==0:
                  last = pending.pop()
                  current_vertex = r.search_by_value(last)
                  second_best = r.search_by_value(pending[-1])
                  if logs:
                        print('--- Out of states---')
                        print(f'Getting from pending:')
                        print(f'Seed: {current_vertex.seed}, Score: {current_vertex.score}')
                        print(format_state(current_vertex.value))
                  continue

            

            #ya filtrados, se calcula la heuristica de cada estado candidato y se ordenan
            heuristics = []
            for st in states:
                  h = verify(st, t) + current_vertex.depth + 1
                  heuristics.append(h)

            heuristics, states, seeds = insort(heuristics, states, seeds)
            heuristics.reverse()
            states.reverse()
            seeds.reverse()

            #Se toma el mejor de todos los estados para continuar con la expansion y los demás se almacenan en pending
            #Ademas, el nodo actual se va al arreglo de checked y el mejor de esta iteracion toma su lugar
            
            # if logs: print('-----------------------------')
            for st, se, h in zip(states, seeds, heuristics):
                  current_vertex.childs.append(Vertex())
                  current_vertex.childs[-1].depth = current_vertex.depth + 1
                  current_vertex.childs[-1].value = st
                  current_vertex.childs[-1].seed = se
                  current_vertex.childs[-1].score = h
                  current_vertex.childs[-1].parent = current_vertex
                  
                #   if logs: print(f'---Added to the tree: \n{format_state(current_vertex.childs[-1].value)}')
            if logs:
                  print('-----------------------------')            
                  print(f'\n---- ST Available ----')
                  for c in current_vertex.childs:
                        print(f'Seed: {c.seed}, Score: {c.score}\n{format_state(c.value)}')

            checked.append(current_vertex.value)

            states.pop()
            
            if len(current_vertex.childs)>1:
                  second = current_vertex.childs[-2]
            current_vertex = current_vertex.childs[-1]
            

            for st in states:
                  pending.append(st)
            
            # if logs:
            #       print(f'--- Pending: {len(pending)}')
            #       print(f'Last: \n{format_state(pending[-1])}')

            #Nos aseguramos que este nodo sea un buen candidato respecto a la iteración anterior.
            if second_best:
                  if current_vertex.score > second_best.score:
                        if logs: print('--- Not the best candidate. Selecting second best...')
                        checked.append(current_vertex.value)
                        current_vertex = second_best
                        second_best = None
                        if current_vertex.value in pending:
                              pending.remove(current_vertex.value)
                            #   if logs:
                            #         print(f'--- Pending: {len(pending)}')
                            #         print(f'Last: \n{format_state(pending[-1])}')
                              
            else:
                  second_best = second
                  if logs:
                        print('--- Second best ---')
                        print(f'Seed: {second_best.seed}, Score: {second_best.score}')
                        print(format_state(second_best.value))
                        
            if logs:
                  print(f'\n---- ST Selected ----')
                  print(f'Seed: {current_vertex.seed}, Score: {current_vertex.score}\n{format_state(current_vertex.value)}')
# Out:
# Searching...
# _______________________________________________
# ----- ST Calculated - Depth: 1 -----
# Seed: up
# ['2', '#', '6']
# ['4', '1', '8']
# ['7', '5', '3']
#
# Seed: down
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '#', '3']
#
# Seed: right
# ['2', '1', '6']
# ['4', '8', '#']
# ['7', '5', '3']
#
# Seed: left
# ['2', '1', '6']
# ['#', '4', '8']
# ['7', '5', '3']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 9
# ['2', '1', '6']
# ['#', '4', '8']
# ['7', '5', '3']
#
# Seed: right, Score: 9
# ['2', '1', '6']
# ['4', '8', '#']
# ['7', '5', '3']
#
# Seed: down, Score: 9
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '#', '3']
#
# Seed: up, Score: 9
# ['2', '#', '6']
# ['4', '1', '8']
# ['7', '5', '3']
#
# --- Second best ---
# Seed: down, Score: 9
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '#', '3']
#
#
# ---- ST Selected ----
# Seed: up, Score: 9
# ['2', '#', '6']
# ['4', '1', '8']
# ['7', '5', '3']
#
# _______________________________________________
# ----- ST Calculated - Depth: 2 -----
# Seed: down
# ['2', '1', '6']
# ['4', '#', '8']
# ['7', '5', '3']
#
# Seed: right
# ['2', '6', '#']
# ['4', '1', '8']
# ['7', '5', '3']
#
# Seed: left
# ['#', '2', '6']
# ['4', '1', '8']
# ['7', '5', '3']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 10
# ['2', '6', '#']
# ['4', '1', '8']
# ['7', '5', '3']
#
# Seed: left, Score: 9
# ['#', '2', '6']
# ['4', '1', '8']
# ['7', '5', '3']
#
#
# ---- ST Selected ----
# Seed: left, Score: 9
# ['#', '2', '6']
# ['4', '1', '8']
# ['7', '5', '3']
#
# _______________________________________________
# ----- ST Calculated - Depth: 3 -----
# Seed: down
# ['4', '2', '6']
# ['#', '1', '8']
# ['7', '5', '3']
#
# Seed: right
# ['2', '#', '6']
# ['4', '1', '8']
# ['7', '5', '3']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: down, Score: 10
# ['4', '2', '6']
# ['#', '1', '8']
# ['7', '5', '3']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: down, Score: 9
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '#', '3']
#
# _______________________________________________
# ----- ST Calculated - Depth: 2 -----
# Seed: up
# ['2', '1', '6']
# ['4', '#', '8']
# ['7', '5', '3']
#
# Seed: right
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '3', '#']
#
# Seed: left
# ['2', '1', '6']
# ['4', '5', '8']
# ['#', '7', '3']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 11
# ['2', '1', '6']
# ['4', '5', '8']
# ['#', '7', '3']
#
# Seed: right, Score: 10
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '3', '#']
#
# --- Second best ---
# Seed: left, Score: 11
# ['2', '1', '6']
# ['4', '5', '8']
# ['#', '7', '3']
#
#
# ---- ST Selected ----
# Seed: right, Score: 10
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '3', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 3 -----
# Seed: up
# ['2', '1', '6']
# ['4', '5', '#']
# ['7', '3', '8']
#
# Seed: left
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '#', '3']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 11
# ['2', '1', '6']
# ['4', '5', '#']
# ['7', '3', '8']
#
#
# ---- ST Selected ----
# Seed: up, Score: 11
# ['2', '1', '6']
# ['4', '5', '#']
# ['7', '3', '8']
#
# _______________________________________________
# ----- ST Calculated - Depth: 4 -----
# Seed: up
# ['2', '1', '#']
# ['4', '5', '6']
# ['7', '3', '8']
#
# Seed: down
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '3', '#']
#
# Seed: left
# ['2', '1', '6']
# ['4', '#', '5']
# ['7', '3', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 12
# ['2', '1', '#']
# ['4', '5', '6']
# ['7', '3', '8']
#
# Seed: left, Score: 11
# ['2', '1', '6']
# ['4', '#', '5']
# ['7', '3', '8']
#
#
# ---- ST Selected ----
# Seed: left, Score: 11
# ['2', '1', '6']
# ['4', '#', '5']
# ['7', '3', '8']
#
# _______________________________________________
# ----- ST Calculated - Depth: 5 -----
# Seed: up
# ['2', '#', '6']
# ['4', '1', '5']
# ['7', '3', '8']
#
# Seed: down
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '#', '8']
#
# Seed: right
# ['2', '1', '6']
# ['4', '5', '#']
# ['7', '3', '8']
#
# Seed: left
# ['2', '1', '6']
# ['#', '4', '5']
# ['7', '3', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 13
# ['2', '1', '6']
# ['#', '4', '5']
# ['7', '3', '8']
#
# Seed: down, Score: 13
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '#', '8']
#
# Seed: up, Score: 13
# ['2', '#', '6']
# ['4', '1', '5']
# ['7', '3', '8']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: left, Score: 11
# ['2', '1', '6']
# ['4', '5', '8']
# ['#', '7', '3']
#
# _______________________________________________
# ----- ST Calculated - Depth: 3 -----
# Seed: up
# ['2', '1', '6']
# ['#', '5', '8']
# ['4', '7', '3']
#
# Seed: right
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '#', '3']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 12
# ['2', '1', '6']
# ['#', '5', '8']
# ['4', '7', '3']
#
# --- Second best ---
# Seed: down, Score: 13
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '#', '8']
#
#
# ---- ST Selected ----
# Seed: up, Score: 12
# ['2', '1', '6']
# ['#', '5', '8']
# ['4', '7', '3']
#
# _______________________________________________
# ----- ST Calculated - Depth: 4 -----
# Seed: up
# ['#', '1', '6']
# ['2', '5', '8']
# ['4', '7', '3']
#
# Seed: down
# ['2', '1', '6']
# ['4', '5', '8']
# ['#', '7', '3']
#
# Seed: right
# ['2', '1', '6']
# ['5', '#', '8']
# ['4', '7', '3']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 13
# ['#', '1', '6']
# ['2', '5', '8']
# ['4', '7', '3']
#
# Seed: right, Score: 12
# ['2', '1', '6']
# ['5', '#', '8']
# ['4', '7', '3']
#
#
# ---- ST Selected ----
# Seed: right, Score: 12
# ['2', '1', '6']
# ['5', '#', '8']
# ['4', '7', '3']
#
# _______________________________________________
# ----- ST Calculated - Depth: 5 -----
# Seed: up
# ['2', '#', '6']
# ['5', '1', '8']
# ['4', '7', '3']
#
# Seed: down
# ['2', '1', '6']
# ['5', '7', '8']
# ['4', '#', '3']
#
# Seed: right
# ['2', '1', '6']
# ['5', '8', '#']
# ['4', '7', '3']
#
# Seed: left
# ['2', '1', '6']
# ['#', '5', '8']
# ['4', '7', '3']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 14
# ['2', '1', '6']
# ['5', '8', '#']
# ['4', '7', '3']
#
# Seed: down, Score: 14
# ['2', '1', '6']
# ['5', '7', '8']
# ['4', '#', '3']
#
# Seed: up, Score: 14
# ['2', '#', '6']
# ['5', '1', '8']
# ['4', '7', '3']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: down, Score: 13
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '#', '8']
#
# _______________________________________________
# ----- ST Calculated - Depth: 6 -----
# Seed: up
# ['2', '1', '6']
# ['4', '#', '5']
# ['7', '3', '8']
#
# Seed: right
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '8', '#']
#
# Seed: left
# ['2', '1', '6']
# ['4', '3', '5']
# ['#', '7', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 15
# ['2', '1', '6']
# ['4', '3', '5']
# ['#', '7', '8']
#
# Seed: right, Score: 14
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '8', '#']
#
# --- Second best ---
# Seed: left, Score: 15
# ['2', '1', '6']
# ['4', '3', '5']
# ['#', '7', '8']
#
#
# ---- ST Selected ----
# Seed: right, Score: 14
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '8', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 7 -----
# Seed: up
# ['2', '1', '6']
# ['4', '3', '#']
# ['7', '8', '5']
#
# Seed: left
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '#', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 14
# ['2', '1', '6']
# ['4', '3', '#']
# ['7', '8', '5']
#
#
# ---- ST Selected ----
# Seed: up, Score: 14
# ['2', '1', '6']
# ['4', '3', '#']
# ['7', '8', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 8 -----
# Seed: up
# ['2', '1', '#']
# ['4', '3', '6']
# ['7', '8', '5']
#
# Seed: down
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '8', '#']
#
# Seed: left
# ['2', '1', '6']
# ['4', '#', '3']
# ['7', '8', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 15
# ['2', '1', '#']
# ['4', '3', '6']
# ['7', '8', '5']
#
# Seed: left, Score: 14
# ['2', '1', '6']
# ['4', '#', '3']
# ['7', '8', '5']
#
#
# ---- ST Selected ----
# Seed: left, Score: 14
# ['2', '1', '6']
# ['4', '#', '3']
# ['7', '8', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 9 -----
# Seed: up
# ['2', '#', '6']
# ['4', '1', '3']
# ['7', '8', '5']
#
# Seed: down
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '#', '5']
#
# Seed: right
# ['2', '1', '6']
# ['4', '3', '#']
# ['7', '8', '5']
#
# Seed: left
# ['2', '1', '6']
# ['#', '4', '3']
# ['7', '8', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 16
# ['2', '1', '6']
# ['#', '4', '3']
# ['7', '8', '5']
#
# Seed: down, Score: 16
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '#', '5']
#
# Seed: up, Score: 16
# ['2', '#', '6']
# ['4', '1', '3']
# ['7', '8', '5']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: left, Score: 15
# ['2', '1', '6']
# ['4', '3', '5']
# ['#', '7', '8']
#
# _______________________________________________
# ----- ST Calculated - Depth: 7 -----
# Seed: up
# ['2', '1', '6']
# ['#', '3', '5']
# ['4', '7', '8']
#
# Seed: right
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '#', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 16
# ['2', '1', '6']
# ['#', '3', '5']
# ['4', '7', '8']
#
# --- Second best ---
# Seed: down, Score: 16
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '#', '5']
#
#
# ---- ST Selected ----
# Seed: up, Score: 16
# ['2', '1', '6']
# ['#', '3', '5']
# ['4', '7', '8']
#
# _______________________________________________
# ----- ST Calculated - Depth: 8 -----
# Seed: up
# ['#', '1', '6']
# ['2', '3', '5']
# ['4', '7', '8']
#
# Seed: down
# ['2', '1', '6']
# ['4', '3', '5']
# ['#', '7', '8']
#
# Seed: right
# ['2', '1', '6']
# ['3', '#', '5']
# ['4', '7', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 17
# ['#', '1', '6']
# ['2', '3', '5']
# ['4', '7', '8']
#
# Seed: right, Score: 16
# ['2', '1', '6']
# ['3', '#', '5']
# ['4', '7', '8']
#
#
# ---- ST Selected ----
# Seed: right, Score: 16
# ['2', '1', '6']
# ['3', '#', '5']
# ['4', '7', '8']
#
# _______________________________________________
# ----- ST Calculated - Depth: 9 -----
# Seed: up
# ['2', '#', '6']
# ['3', '1', '5']
# ['4', '7', '8']
#
# Seed: down
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '#', '8']
#
# Seed: right
# ['2', '1', '6']
# ['3', '5', '#']
# ['4', '7', '8']
#
# Seed: left
# ['2', '1', '6']
# ['#', '3', '5']
# ['4', '7', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 18
# ['2', '1', '6']
# ['3', '5', '#']
# ['4', '7', '8']
#
# Seed: down, Score: 18
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '#', '8']
#
# Seed: up, Score: 18
# ['2', '#', '6']
# ['3', '1', '5']
# ['4', '7', '8']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: down, Score: 16
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '#', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 10 -----
# Seed: up
# ['2', '1', '6']
# ['4', '#', '3']
# ['7', '8', '5']
#
# Seed: right
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '5', '#']
#
# Seed: left
# ['2', '1', '6']
# ['4', '8', '3']
# ['#', '7', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 18
# ['2', '1', '6']
# ['4', '8', '3']
# ['#', '7', '5']
#
# Seed: right, Score: 18
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '5', '#']
#
# --- Second best ---
# Seed: left, Score: 18
# ['2', '1', '6']
# ['4', '8', '3']
# ['#', '7', '5']
#
#
# ---- ST Selected ----
# Seed: right, Score: 18
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '5', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 11 -----
# Seed: up
# ['2', '1', '6']
# ['4', '8', '#']
# ['7', '5', '3']
#
# Seed: left
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '#', '5']
#
# --- Out of states---
# Getting from pending:
# Seed: left, Score: 18
# ['2', '1', '6']
# ['4', '8', '3']
# ['#', '7', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 11 -----
# Seed: up
# ['2', '1', '6']
# ['#', '8', '3']
# ['4', '7', '5']
#
# Seed: right
# ['2', '1', '6']
# ['4', '8', '3']
# ['7', '#', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 19
# ['2', '1', '6']
# ['#', '8', '3']
# ['4', '7', '5']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: down, Score: 18
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '#', '8']
#
# _______________________________________________
# ----- ST Calculated - Depth: 10 -----
# Seed: up
# ['2', '1', '6']
# ['3', '#', '5']
# ['4', '7', '8']
#
# Seed: right
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '8', '#']
#
# Seed: left
# ['2', '1', '6']
# ['3', '7', '5']
# ['#', '4', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 19
# ['2', '1', '6']
# ['3', '7', '5']
# ['#', '4', '8']
#
# Seed: right, Score: 19
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '8', '#']
#
# --- Second best ---
# Seed: left, Score: 19
# ['2', '1', '6']
# ['3', '7', '5']
# ['#', '4', '8']
#
#
# ---- ST Selected ----
# Seed: right, Score: 19
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '8', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 11 -----
# Seed: up
# ['2', '1', '6']
# ['3', '7', '#']
# ['4', '8', '5']
#
# Seed: left
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '#', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 19
# ['2', '1', '6']
# ['3', '7', '#']
# ['4', '8', '5']
#
#
# ---- ST Selected ----
# Seed: up, Score: 19
# ['2', '1', '6']
# ['3', '7', '#']
# ['4', '8', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 12 -----
# Seed: up
# ['2', '1', '#']
# ['3', '7', '6']
# ['4', '8', '5']
#
# Seed: down
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '8', '#']
#
# Seed: left
# ['2', '1', '6']
# ['3', '#', '7']
# ['4', '8', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 20
# ['2', '1', '#']
# ['3', '7', '6']
# ['4', '8', '5']
#
# Seed: left, Score: 19
# ['2', '1', '6']
# ['3', '#', '7']
# ['4', '8', '5']
#
#
# ---- ST Selected ----
# Seed: left, Score: 19
# ['2', '1', '6']
# ['3', '#', '7']
# ['4', '8', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 13 -----
# Seed: up
# ['2', '#', '6']
# ['3', '1', '7']
# ['4', '8', '5']
#
# Seed: down
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '#', '5']
#
# Seed: right
# ['2', '1', '6']
# ['3', '7', '#']
# ['4', '8', '5']
#
# Seed: left
# ['2', '1', '6']
# ['#', '3', '7']
# ['4', '8', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 21
# ['2', '1', '6']
# ['#', '3', '7']
# ['4', '8', '5']
#
# Seed: down, Score: 21
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '#', '5']
#
# Seed: up, Score: 21
# ['2', '#', '6']
# ['3', '1', '7']
# ['4', '8', '5']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: left, Score: 19
# ['2', '1', '6']
# ['3', '7', '5']
# ['#', '4', '8']
#
# _______________________________________________
# ----- ST Calculated - Depth: 11 -----
# Seed: up
# ['2', '1', '6']
# ['#', '7', '5']
# ['3', '4', '8']
#
# Seed: right
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '#', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 20
# ['2', '1', '6']
# ['#', '7', '5']
# ['3', '4', '8']
#
# --- Second best ---
# Seed: down, Score: 21
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '#', '5']
#
#
# ---- ST Selected ----
# Seed: up, Score: 20
# ['2', '1', '6']
# ['#', '7', '5']
# ['3', '4', '8']
#
# _______________________________________________
# ----- ST Calculated - Depth: 12 -----
# Seed: up
# ['#', '1', '6']
# ['2', '7', '5']
# ['3', '4', '8']
#
# Seed: down
# ['2', '1', '6']
# ['3', '7', '5']
# ['#', '4', '8']
#
# Seed: right
# ['2', '1', '6']
# ['7', '#', '5']
# ['3', '4', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 21
# ['#', '1', '6']
# ['2', '7', '5']
# ['3', '4', '8']
#
# Seed: right, Score: 20
# ['2', '1', '6']
# ['7', '#', '5']
# ['3', '4', '8']
#
#
# ---- ST Selected ----
# Seed: right, Score: 20
# ['2', '1', '6']
# ['7', '#', '5']
# ['3', '4', '8']
#
# _______________________________________________
# ----- ST Calculated - Depth: 13 -----
# Seed: up
# ['2', '#', '6']
# ['7', '1', '5']
# ['3', '4', '8']
#
# Seed: down
# ['2', '1', '6']
# ['7', '4', '5']
# ['3', '#', '8']
#
# Seed: right
# ['2', '1', '6']
# ['7', '5', '#']
# ['3', '4', '8']
#
# Seed: left
# ['2', '1', '6']
# ['#', '7', '5']
# ['3', '4', '8']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 22
# ['2', '1', '6']
# ['7', '5', '#']
# ['3', '4', '8']
#
# Seed: down, Score: 22
# ['2', '1', '6']
# ['7', '4', '5']
# ['3', '#', '8']
#
# Seed: up, Score: 22
# ['2', '#', '6']
# ['7', '1', '5']
# ['3', '4', '8']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: down, Score: 21
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '#', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 14 -----
# Seed: up
# ['2', '1', '6']
# ['3', '#', '7']
# ['4', '8', '5']
#
# Seed: right
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '5', '#']
#
# Seed: left
# ['2', '1', '6']
# ['3', '8', '7']
# ['#', '4', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 23
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '5', '#']
#
# Seed: left, Score: 22
# ['2', '1', '6']
# ['3', '8', '7']
# ['#', '4', '5']
#
# --- Second best ---
# Seed: right, Score: 23
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '5', '#']
#
#
# ---- ST Selected ----
# Seed: left, Score: 22
# ['2', '1', '6']
# ['3', '8', '7']
# ['#', '4', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 15 -----
# Seed: up
# ['2', '1', '6']
# ['#', '8', '7']
# ['3', '4', '5']
#
# Seed: right
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '#', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 23
# ['2', '1', '6']
# ['#', '8', '7']
# ['3', '4', '5']
#
#
# ---- ST Selected ----
# Seed: up, Score: 23
# ['2', '1', '6']
# ['#', '8', '7']
# ['3', '4', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 16 -----
# Seed: up
# ['#', '1', '6']
# ['2', '8', '7']
# ['3', '4', '5']
#
# Seed: down
# ['2', '1', '6']
# ['3', '8', '7']
# ['#', '4', '5']
#
# Seed: right
# ['2', '1', '6']
# ['8', '#', '7']
# ['3', '4', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 24
# ['#', '1', '6']
# ['2', '8', '7']
# ['3', '4', '5']
#
# Seed: right, Score: 22
# ['2', '1', '6']
# ['8', '#', '7']
# ['3', '4', '5']
#
#
# ---- ST Selected ----
# Seed: right, Score: 22
# ['2', '1', '6']
# ['8', '#', '7']
# ['3', '4', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 17 -----
# Seed: up
# ['2', '#', '6']
# ['8', '1', '7']
# ['3', '4', '5']
#
# Seed: down
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '#', '5']
#
# Seed: right
# ['2', '1', '6']
# ['8', '7', '#']
# ['3', '4', '5']
#
# Seed: left
# ['2', '1', '6']
# ['#', '8', '7']
# ['3', '4', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 24
# ['2', '1', '6']
# ['8', '7', '#']
# ['3', '4', '5']
#
# Seed: down, Score: 24
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '#', '5']
#
# Seed: up, Score: 24
# ['2', '#', '6']
# ['8', '1', '7']
# ['3', '4', '5']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: right, Score: 23
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '5', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 15 -----
# Seed: up
# ['2', '1', '6']
# ['3', '8', '#']
# ['4', '5', '7']
#
# Seed: left
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '#', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 24
# ['2', '1', '6']
# ['3', '8', '#']
# ['4', '5', '7']
#
# --- Second best ---
# Seed: down, Score: 24
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '#', '5']
#
#
# ---- ST Selected ----
# Seed: up, Score: 24
# ['2', '1', '6']
# ['3', '8', '#']
# ['4', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 16 -----
# Seed: up
# ['2', '1', '#']
# ['3', '8', '6']
# ['4', '5', '7']
#
# Seed: down
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '5', '#']
#
# Seed: left
# ['2', '1', '6']
# ['3', '#', '8']
# ['4', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 25
# ['2', '1', '#']
# ['3', '8', '6']
# ['4', '5', '7']
#
# Seed: left, Score: 24
# ['2', '1', '6']
# ['3', '#', '8']
# ['4', '5', '7']
#
#
# ---- ST Selected ----
# Seed: left, Score: 24
# ['2', '1', '6']
# ['3', '#', '8']
# ['4', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 17 -----
# Seed: up
# ['2', '#', '6']
# ['3', '1', '8']
# ['4', '5', '7']
#
# Seed: down
# ['2', '1', '6']
# ['3', '5', '8']
# ['4', '#', '7']
#
# Seed: right
# ['2', '1', '6']
# ['3', '8', '#']
# ['4', '5', '7']
#
# Seed: left
# ['2', '1', '6']
# ['#', '3', '8']
# ['4', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 26
# ['2', '1', '6']
# ['#', '3', '8']
# ['4', '5', '7']
#
# Seed: down, Score: 26
# ['2', '1', '6']
# ['3', '5', '8']
# ['4', '#', '7']
#
# Seed: up, Score: 26
# ['2', '#', '6']
# ['3', '1', '8']
# ['4', '5', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: down, Score: 24
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '#', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 18 -----
# Seed: up
# ['2', '1', '6']
# ['8', '#', '7']
# ['3', '4', '5']
#
# Seed: right
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '5', '#']
#
# Seed: left
# ['2', '1', '6']
# ['8', '4', '7']
# ['#', '3', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 26
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '5', '#']
#
# Seed: left, Score: 25
# ['2', '1', '6']
# ['8', '4', '7']
# ['#', '3', '5']
#
# --- Second best ---
# Seed: right, Score: 26
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '5', '#']
#
#
# ---- ST Selected ----
# Seed: left, Score: 25
# ['2', '1', '6']
# ['8', '4', '7']
# ['#', '3', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 19 -----
# Seed: up
# ['2', '1', '6']
# ['#', '4', '7']
# ['8', '3', '5']
#
# Seed: right
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '#', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 27
# ['2', '1', '6']
# ['#', '4', '7']
# ['8', '3', '5']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: right, Score: 26
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '5', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 19 -----
# Seed: up
# ['2', '1', '6']
# ['8', '4', '#']
# ['3', '5', '7']
#
# Seed: left
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '#', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 27
# ['2', '1', '6']
# ['8', '4', '#']
# ['3', '5', '7']
#
# --- Second best ---
# Seed: right, Score: 26
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '5', '#']
#
#
# ---- ST Selected ----
# Seed: up, Score: 27
# ['2', '1', '6']
# ['8', '4', '#']
# ['3', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 20 -----
# Seed: up
# ['2', '1', '#']
# ['8', '4', '6']
# ['3', '5', '7']
#
# Seed: down
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '5', '#']
#
# Seed: left
# ['2', '1', '6']
# ['8', '#', '4']
# ['3', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 28
# ['2', '1', '#']
# ['8', '4', '6']
# ['3', '5', '7']
#
# Seed: left, Score: 26
# ['2', '1', '6']
# ['8', '#', '4']
# ['3', '5', '7']
#
#
# ---- ST Selected ----
# Seed: left, Score: 26
# ['2', '1', '6']
# ['8', '#', '4']
# ['3', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 21 -----
# Seed: up
# ['2', '#', '6']
# ['8', '1', '4']
# ['3', '5', '7']
#
# Seed: down
# ['2', '1', '6']
# ['8', '5', '4']
# ['3', '#', '7']
#
# Seed: right
# ['2', '1', '6']
# ['8', '4', '#']
# ['3', '5', '7']
#
# Seed: left
# ['2', '1', '6']
# ['#', '8', '4']
# ['3', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 29
# ['2', '1', '6']
# ['#', '8', '4']
# ['3', '5', '7']
#
# Seed: down, Score: 28
# ['2', '1', '6']
# ['8', '5', '4']
# ['3', '#', '7']
#
# Seed: up, Score: 28
# ['2', '#', '6']
# ['8', '1', '4']
# ['3', '5', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: right, Score: 26
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '5', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 19 -----
# Seed: up
# ['2', '1', '6']
# ['8', '4', '#']
# ['3', '5', '7']
#
# Seed: left
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '#', '5']
#
# --- Out of states---
# Getting from pending:
# Seed: down, Score: 28
# ['2', '1', '6']
# ['8', '5', '4']
# ['3', '#', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 22 -----
# Seed: up
# ['2', '1', '6']
# ['8', '#', '4']
# ['3', '5', '7']
#
# Seed: right
# ['2', '1', '6']
# ['8', '5', '4']
# ['3', '7', '#']
#
# Seed: left
# ['2', '1', '6']
# ['8', '5', '4']
# ['#', '3', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 29
# ['2', '1', '6']
# ['8', '5', '4']
# ['#', '3', '7']
#
# Seed: right, Score: 29
# ['2', '1', '6']
# ['8', '5', '4']
# ['3', '7', '#']
#
#
# ---- ST Selected ----
# Seed: right, Score: 29
# ['2', '1', '6']
# ['8', '5', '4']
# ['3', '7', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 23 -----
# Seed: up
# ['2', '1', '6']
# ['8', '5', '#']
# ['3', '7', '4']
#
# Seed: left
# ['2', '1', '6']
# ['8', '5', '4']
# ['3', '#', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 31
# ['2', '1', '6']
# ['8', '5', '#']
# ['3', '7', '4']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: left, Score: 29
# ['2', '1', '6']
# ['#', '8', '4']
# ['3', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 22 -----
# Seed: up
# ['#', '1', '6']
# ['2', '8', '4']
# ['3', '5', '7']
#
# Seed: down
# ['2', '1', '6']
# ['3', '8', '4']
# ['#', '5', '7']
#
# Seed: right
# ['2', '1', '6']
# ['8', '#', '4']
# ['3', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: down, Score: 30
# ['2', '1', '6']
# ['3', '8', '4']
# ['#', '5', '7']
#
# Seed: up, Score: 30
# ['#', '1', '6']
# ['2', '8', '4']
# ['3', '5', '7']
#
# --- Second best ---
# Seed: down, Score: 30
# ['2', '1', '6']
# ['3', '8', '4']
# ['#', '5', '7']
#
#
# ---- ST Selected ----
# Seed: up, Score: 30
# ['#', '1', '6']
# ['2', '8', '4']
# ['3', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 23 -----
# Seed: down
# ['2', '1', '6']
# ['#', '8', '4']
# ['3', '5', '7']
#
# Seed: right
# ['1', '#', '6']
# ['2', '8', '4']
# ['3', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 30
# ['1', '#', '6']
# ['2', '8', '4']
# ['3', '5', '7']
#
#
# ---- ST Selected ----
# Seed: right, Score: 30
# ['1', '#', '6']
# ['2', '8', '4']
# ['3', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 24 -----
# Seed: down
# ['1', '8', '6']
# ['2', '#', '4']
# ['3', '5', '7']
#
# Seed: right
# ['1', '6', '#']
# ['2', '8', '4']
# ['3', '5', '7']
#
# Seed: left
# ['#', '1', '6']
# ['2', '8', '4']
# ['3', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 31
# ['1', '6', '#']
# ['2', '8', '4']
# ['3', '5', '7']
#
# Seed: down, Score: 30
# ['1', '8', '6']
# ['2', '#', '4']
# ['3', '5', '7']
#
#
# ---- ST Selected ----
# Seed: down, Score: 30
# ['1', '8', '6']
# ['2', '#', '4']
# ['3', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 25 -----
# Seed: up
# ['1', '#', '6']
# ['2', '8', '4']
# ['3', '5', '7']
#
# Seed: down
# ['1', '8', '6']
# ['2', '5', '4']
# ['3', '#', '7']
#
# Seed: right
# ['1', '8', '6']
# ['2', '4', '#']
# ['3', '5', '7']
#
# Seed: left
# ['1', '8', '6']
# ['#', '2', '4']
# ['3', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 33
# ['1', '8', '6']
# ['2', '4', '#']
# ['3', '5', '7']
#
# Seed: left, Score: 32
# ['1', '8', '6']
# ['#', '2', '4']
# ['3', '5', '7']
#
# Seed: down, Score: 32
# ['1', '8', '6']
# ['2', '5', '4']
# ['3', '#', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: down, Score: 30
# ['2', '1', '6']
# ['3', '8', '4']
# ['#', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 23 -----
# Seed: up
# ['2', '1', '6']
# ['#', '8', '4']
# ['3', '5', '7']
#
# Seed: right
# ['2', '1', '6']
# ['3', '8', '4']
# ['5', '#', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 31
# ['2', '1', '6']
# ['3', '8', '4']
# ['5', '#', '7']
#
# --- Second best ---
# Seed: left, Score: 32
# ['1', '8', '6']
# ['#', '2', '4']
# ['3', '5', '7']
#
#
# ---- ST Selected ----
# Seed: right, Score: 31
# ['2', '1', '6']
# ['3', '8', '4']
# ['5', '#', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 24 -----
# Seed: up
# ['2', '1', '6']
# ['3', '#', '4']
# ['5', '8', '7']
#
# Seed: right
# ['2', '1', '6']
# ['3', '8', '4']
# ['5', '7', '#']
#
# Seed: left
# ['2', '1', '6']
# ['3', '8', '4']
# ['#', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 32
# ['2', '1', '6']
# ['3', '8', '4']
# ['5', '7', '#']
#
# Seed: up, Score: 31
# ['2', '1', '6']
# ['3', '#', '4']
# ['5', '8', '7']
#
#
# ---- ST Selected ----
# Seed: up, Score: 31
# ['2', '1', '6']
# ['3', '#', '4']
# ['5', '8', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 25 -----
# Seed: up
# ['2', '#', '6']
# ['3', '1', '4']
# ['5', '8', '7']
#
# Seed: down
# ['2', '1', '6']
# ['3', '8', '4']
# ['5', '#', '7']
#
# Seed: right
# ['2', '1', '6']
# ['3', '4', '#']
# ['5', '8', '7']
#
# Seed: left
# ['2', '1', '6']
# ['#', '3', '4']
# ['5', '8', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 34
# ['2', '1', '6']
# ['3', '4', '#']
# ['5', '8', '7']
#
# Seed: left, Score: 33
# ['2', '1', '6']
# ['#', '3', '4']
# ['5', '8', '7']
#
# Seed: up, Score: 33
# ['2', '#', '6']
# ['3', '1', '4']
# ['5', '8', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: left, Score: 32
# ['1', '8', '6']
# ['#', '2', '4']
# ['3', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 26 -----
# Seed: up
# ['#', '8', '6']
# ['1', '2', '4']
# ['3', '5', '7']
#
# Seed: down
# ['1', '8', '6']
# ['3', '2', '4']
# ['#', '5', '7']
#
# Seed: right
# ['1', '8', '6']
# ['2', '#', '4']
# ['3', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 34
# ['#', '8', '6']
# ['1', '2', '4']
# ['3', '5', '7']
#
# Seed: down, Score: 33
# ['1', '8', '6']
# ['3', '2', '4']
# ['#', '5', '7']
#
# --- Second best ---
# Seed: up, Score: 34
# ['#', '8', '6']
# ['1', '2', '4']
# ['3', '5', '7']
#
#
# ---- ST Selected ----
# Seed: down, Score: 33
# ['1', '8', '6']
# ['3', '2', '4']
# ['#', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 27 -----
# Seed: up
# ['1', '8', '6']
# ['#', '2', '4']
# ['3', '5', '7']
#
# Seed: right
# ['1', '8', '6']
# ['3', '2', '4']
# ['5', '#', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 34
# ['1', '8', '6']
# ['3', '2', '4']
# ['5', '#', '7']
#
#
# ---- ST Selected ----
# Seed: right, Score: 34
# ['1', '8', '6']
# ['3', '2', '4']
# ['5', '#', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 28 -----
# Seed: up
# ['1', '8', '6']
# ['3', '#', '4']
# ['5', '2', '7']
#
# Seed: right
# ['1', '8', '6']
# ['3', '2', '4']
# ['5', '7', '#']
#
# Seed: left
# ['1', '8', '6']
# ['3', '2', '4']
# ['#', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 35
# ['1', '8', '6']
# ['3', '2', '4']
# ['5', '7', '#']
#
# Seed: up, Score: 34
# ['1', '8', '6']
# ['3', '#', '4']
# ['5', '2', '7']
#
#
# ---- ST Selected ----
# Seed: up, Score: 34
# ['1', '8', '6']
# ['3', '#', '4']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 29 -----
# Seed: up
# ['1', '#', '6']
# ['3', '8', '4']
# ['5', '2', '7']
#
# Seed: down
# ['1', '8', '6']
# ['3', '2', '4']
# ['5', '#', '7']
#
# Seed: right
# ['1', '8', '6']
# ['3', '4', '#']
# ['5', '2', '7']
#
# Seed: left
# ['1', '8', '6']
# ['#', '3', '4']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 37
# ['1', '8', '6']
# ['3', '4', '#']
# ['5', '2', '7']
#
# Seed: left, Score: 36
# ['1', '8', '6']
# ['#', '3', '4']
# ['5', '2', '7']
#
# Seed: up, Score: 36
# ['1', '#', '6']
# ['3', '8', '4']
# ['5', '2', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: up, Score: 34
# ['#', '8', '6']
# ['1', '2', '4']
# ['3', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 27 -----
# Seed: down
# ['1', '8', '6']
# ['#', '2', '4']
# ['3', '5', '7']
#
# Seed: right
# ['8', '#', '6']
# ['1', '2', '4']
# ['3', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 35
# ['8', '#', '6']
# ['1', '2', '4']
# ['3', '5', '7']
#
# --- Second best ---
# Seed: left, Score: 36
# ['1', '8', '6']
# ['#', '3', '4']
# ['5', '2', '7']
#
#
# ---- ST Selected ----
# Seed: right, Score: 35
# ['8', '#', '6']
# ['1', '2', '4']
# ['3', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 28 -----
# Seed: down
# ['8', '2', '6']
# ['1', '#', '4']
# ['3', '5', '7']
#
# Seed: right
# ['8', '6', '#']
# ['1', '2', '4']
# ['3', '5', '7']
#
# Seed: left
# ['#', '8', '6']
# ['1', '2', '4']
# ['3', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 36
# ['8', '6', '#']
# ['1', '2', '4']
# ['3', '5', '7']
#
# Seed: down, Score: 34
# ['8', '2', '6']
# ['1', '#', '4']
# ['3', '5', '7']
#
#
# ---- ST Selected ----
# Seed: down, Score: 34
# ['8', '2', '6']
# ['1', '#', '4']
# ['3', '5', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 29 -----
# Seed: up
# ['8', '#', '6']
# ['1', '2', '4']
# ['3', '5', '7']
#
# Seed: down
# ['8', '2', '6']
# ['1', '5', '4']
# ['3', '#', '7']
#
# Seed: right
# ['8', '2', '6']
# ['1', '4', '#']
# ['3', '5', '7']
#
# Seed: left
# ['8', '2', '6']
# ['#', '1', '4']
# ['3', '5', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 37
# ['8', '2', '6']
# ['1', '4', '#']
# ['3', '5', '7']
#
# Seed: left, Score: 36
# ['8', '2', '6']
# ['#', '1', '4']
# ['3', '5', '7']
#
# Seed: down, Score: 36
# ['8', '2', '6']
# ['1', '5', '4']
# ['3', '#', '7']
#
#
# ---- ST Selected ----
# Seed: down, Score: 36
# ['8', '2', '6']
# ['1', '5', '4']
# ['3', '#', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 30 -----
# Seed: up
# ['8', '2', '6']
# ['1', '#', '4']
# ['3', '5', '7']
#
# Seed: right
# ['8', '2', '6']
# ['1', '5', '4']
# ['3', '7', '#']
#
# Seed: left
# ['8', '2', '6']
# ['1', '5', '4']
# ['#', '3', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 37
# ['8', '2', '6']
# ['1', '5', '4']
# ['#', '3', '7']
#
# Seed: right, Score: 37
# ['8', '2', '6']
# ['1', '5', '4']
# ['3', '7', '#']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: left, Score: 36
# ['1', '8', '6']
# ['#', '3', '4']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 30 -----
# Seed: up
# ['#', '8', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
# Seed: down
# ['1', '8', '6']
# ['5', '3', '4']
# ['#', '2', '7']
#
# Seed: right
# ['1', '8', '6']
# ['3', '#', '4']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 38
# ['#', '8', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
# Seed: down, Score: 37
# ['1', '8', '6']
# ['5', '3', '4']
# ['#', '2', '7']
#
# --- Second best ---
# Seed: up, Score: 38
# ['#', '8', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
#
# ---- ST Selected ----
# Seed: down, Score: 37
# ['1', '8', '6']
# ['5', '3', '4']
# ['#', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 31 -----
# Seed: up
# ['1', '8', '6']
# ['#', '3', '4']
# ['5', '2', '7']
#
# Seed: right
# ['1', '8', '6']
# ['5', '3', '4']
# ['2', '#', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 38
# ['1', '8', '6']
# ['5', '3', '4']
# ['2', '#', '7']
#
#
# ---- ST Selected ----
# Seed: right, Score: 38
# ['1', '8', '6']
# ['5', '3', '4']
# ['2', '#', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 32 -----
# Seed: up
# ['1', '8', '6']
# ['5', '#', '4']
# ['2', '3', '7']
#
# Seed: right
# ['1', '8', '6']
# ['5', '3', '4']
# ['2', '7', '#']
#
# Seed: left
# ['1', '8', '6']
# ['5', '3', '4']
# ['#', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 39
# ['1', '8', '6']
# ['5', '3', '4']
# ['2', '7', '#']
#
# Seed: up, Score: 38
# ['1', '8', '6']
# ['5', '#', '4']
# ['2', '3', '7']
#
#
# ---- ST Selected ----
# Seed: up, Score: 38
# ['1', '8', '6']
# ['5', '#', '4']
# ['2', '3', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 33 -----
# Seed: up
# ['1', '#', '6']
# ['5', '8', '4']
# ['2', '3', '7']
#
# Seed: down
# ['1', '8', '6']
# ['5', '3', '4']
# ['2', '#', '7']
#
# Seed: right
# ['1', '8', '6']
# ['5', '4', '#']
# ['2', '3', '7']
#
# Seed: left
# ['1', '8', '6']
# ['#', '5', '4']
# ['2', '3', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 41
# ['1', '8', '6']
# ['5', '4', '#']
# ['2', '3', '7']
#
# Seed: left, Score: 40
# ['1', '8', '6']
# ['#', '5', '4']
# ['2', '3', '7']
#
# Seed: up, Score: 40
# ['1', '#', '6']
# ['5', '8', '4']
# ['2', '3', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: up, Score: 38
# ['#', '8', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 31 -----
# Seed: down
# ['1', '8', '6']
# ['#', '3', '4']
# ['5', '2', '7']
#
# Seed: right
# ['8', '#', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 39
# ['8', '#', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
# --- Second best ---
# Seed: left, Score: 40
# ['1', '8', '6']
# ['#', '5', '4']
# ['2', '3', '7']
#
#
# ---- ST Selected ----
# Seed: right, Score: 39
# ['8', '#', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 32 -----
# Seed: down
# ['8', '3', '6']
# ['1', '#', '4']
# ['5', '2', '7']
#
# Seed: right
# ['8', '6', '#']
# ['1', '3', '4']
# ['5', '2', '7']
#
# Seed: left
# ['#', '8', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 40
# ['8', '6', '#']
# ['1', '3', '4']
# ['5', '2', '7']
#
# Seed: down, Score: 39
# ['8', '3', '6']
# ['1', '#', '4']
# ['5', '2', '7']
#
#
# ---- ST Selected ----
# Seed: down, Score: 39
# ['8', '3', '6']
# ['1', '#', '4']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 33 -----
# Seed: up
# ['8', '#', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
# Seed: down
# ['8', '3', '6']
# ['1', '2', '4']
# ['5', '#', '7']
#
# Seed: right
# ['8', '3', '6']
# ['1', '4', '#']
# ['5', '2', '7']
#
# Seed: left
# ['8', '3', '6']
# ['#', '1', '4']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 42
# ['8', '3', '6']
# ['1', '4', '#']
# ['5', '2', '7']
#
# Seed: left, Score: 41
# ['8', '3', '6']
# ['#', '1', '4']
# ['5', '2', '7']
#
# Seed: down, Score: 41
# ['8', '3', '6']
# ['1', '2', '4']
# ['5', '#', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: left, Score: 40
# ['1', '8', '6']
# ['#', '5', '4']
# ['2', '3', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 34 -----
# Seed: up
# ['#', '8', '6']
# ['1', '5', '4']
# ['2', '3', '7']
#
# Seed: down
# ['1', '8', '6']
# ['2', '5', '4']
# ['#', '3', '7']
#
# Seed: right
# ['1', '8', '6']
# ['5', '#', '4']
# ['2', '3', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 42
# ['#', '8', '6']
# ['1', '5', '4']
# ['2', '3', '7']
#
# Seed: down, Score: 41
# ['1', '8', '6']
# ['2', '5', '4']
# ['#', '3', '7']
#
# --- Second best ---
# Seed: up, Score: 42
# ['#', '8', '6']
# ['1', '5', '4']
# ['2', '3', '7']
#
#
# ---- ST Selected ----
# Seed: down, Score: 41
# ['1', '8', '6']
# ['2', '5', '4']
# ['#', '3', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 35 -----
# Seed: up
# ['1', '8', '6']
# ['#', '5', '4']
# ['2', '3', '7']
#
# Seed: right
# ['1', '8', '6']
# ['2', '5', '4']
# ['3', '#', '7']
#
# --- Out of states---
# Getting from pending:
# Seed: up, Score: 42
# ['#', '8', '6']
# ['1', '5', '4']
# ['2', '3', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 35 -----
# Seed: down
# ['1', '8', '6']
# ['#', '5', '4']
# ['2', '3', '7']
#
# Seed: right
# ['8', '#', '6']
# ['1', '5', '4']
# ['2', '3', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 43
# ['8', '#', '6']
# ['1', '5', '4']
# ['2', '3', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: left, Score: 41
# ['8', '3', '6']
# ['#', '1', '4']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 34 -----
# Seed: up
# ['#', '3', '6']
# ['8', '1', '4']
# ['5', '2', '7']
#
# Seed: down
# ['8', '3', '6']
# ['5', '1', '4']
# ['#', '2', '7']
#
# Seed: right
# ['8', '3', '6']
# ['1', '#', '4']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: down, Score: 42
# ['8', '3', '6']
# ['5', '1', '4']
# ['#', '2', '7']
#
# Seed: up, Score: 41
# ['#', '3', '6']
# ['8', '1', '4']
# ['5', '2', '7']
#
# --- Second best ---
# Seed: down, Score: 42
# ['8', '3', '6']
# ['5', '1', '4']
# ['#', '2', '7']
#
#
# ---- ST Selected ----
# Seed: up, Score: 41
# ['#', '3', '6']
# ['8', '1', '4']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 35 -----
# Seed: down
# ['8', '3', '6']
# ['#', '1', '4']
# ['5', '2', '7']
#
# Seed: right
# ['3', '#', '6']
# ['8', '1', '4']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 42
# ['3', '#', '6']
# ['8', '1', '4']
# ['5', '2', '7']
#
#
# ---- ST Selected ----
# Seed: right, Score: 42
# ['3', '#', '6']
# ['8', '1', '4']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 36 -----
# Seed: down
# ['3', '1', '6']
# ['8', '#', '4']
# ['5', '2', '7']
#
# Seed: right
# ['3', '6', '#']
# ['8', '1', '4']
# ['5', '2', '7']
#
# Seed: left
# ['#', '3', '6']
# ['8', '1', '4']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 43
# ['3', '6', '#']
# ['8', '1', '4']
# ['5', '2', '7']
#
# Seed: down, Score: 42
# ['3', '1', '6']
# ['8', '#', '4']
# ['5', '2', '7']
#
#
# ---- ST Selected ----
# Seed: down, Score: 42
# ['3', '1', '6']
# ['8', '#', '4']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 37 -----
# Seed: up
# ['3', '#', '6']
# ['8', '1', '4']
# ['5', '2', '7']
#
# Seed: down
# ['3', '1', '6']
# ['8', '2', '4']
# ['5', '#', '7']
#
# Seed: right
# ['3', '1', '6']
# ['8', '4', '#']
# ['5', '2', '7']
#
# Seed: left
# ['3', '1', '6']
# ['#', '8', '4']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 45
# ['3', '1', '6']
# ['#', '8', '4']
# ['5', '2', '7']
#
# Seed: right, Score: 45
# ['3', '1', '6']
# ['8', '4', '#']
# ['5', '2', '7']
#
# Seed: down, Score: 44
# ['3', '1', '6']
# ['8', '2', '4']
# ['5', '#', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: down, Score: 42
# ['8', '3', '6']
# ['5', '1', '4']
# ['#', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 35 -----
# Seed: up
# ['8', '3', '6']
# ['#', '1', '4']
# ['5', '2', '7']
#
# Seed: right
# ['8', '3', '6']
# ['5', '1', '4']
# ['2', '#', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 43
# ['8', '3', '6']
# ['5', '1', '4']
# ['2', '#', '7']
#
# --- Second best ---
# Seed: right, Score: 45
# ['3', '1', '6']
# ['8', '4', '#']
# ['5', '2', '7']
#
#
# ---- ST Selected ----
# Seed: right, Score: 43
# ['8', '3', '6']
# ['5', '1', '4']
# ['2', '#', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 36 -----
# Seed: up
# ['8', '3', '6']
# ['5', '#', '4']
# ['2', '1', '7']
#
# Seed: right
# ['8', '3', '6']
# ['5', '1', '4']
# ['2', '7', '#']
#
# Seed: left
# ['8', '3', '6']
# ['5', '1', '4']
# ['#', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 44
# ['8', '3', '6']
# ['5', '1', '4']
# ['2', '7', '#']
#
# Seed: up, Score: 43
# ['8', '3', '6']
# ['5', '#', '4']
# ['2', '1', '7']
#
#
# ---- ST Selected ----
# Seed: up, Score: 43
# ['8', '3', '6']
# ['5', '#', '4']
# ['2', '1', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 37 -----
# Seed: up
# ['8', '#', '6']
# ['5', '3', '4']
# ['2', '1', '7']
#
# Seed: down
# ['8', '3', '6']
# ['5', '1', '4']
# ['2', '#', '7']
#
# Seed: right
# ['8', '3', '6']
# ['5', '4', '#']
# ['2', '1', '7']
#
# Seed: left
# ['8', '3', '6']
# ['#', '5', '4']
# ['2', '1', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 46
# ['8', '3', '6']
# ['5', '4', '#']
# ['2', '1', '7']
#
# Seed: left, Score: 45
# ['8', '3', '6']
# ['#', '5', '4']
# ['2', '1', '7']
#
# Seed: up, Score: 45
# ['8', '#', '6']
# ['5', '3', '4']
# ['2', '1', '7']
#
#
# ---- ST Selected ----
# Seed: up, Score: 45
# ['8', '#', '6']
# ['5', '3', '4']
# ['2', '1', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 38 -----
# Seed: down
# ['8', '3', '6']
# ['5', '#', '4']
# ['2', '1', '7']
#
# Seed: right
# ['8', '6', '#']
# ['5', '3', '4']
# ['2', '1', '7']
#
# Seed: left
# ['#', '8', '6']
# ['5', '3', '4']
# ['2', '1', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 46
# ['#', '8', '6']
# ['5', '3', '4']
# ['2', '1', '7']
#
# Seed: right, Score: 46
# ['8', '6', '#']
# ['5', '3', '4']
# ['2', '1', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: right, Score: 45
# ['3', '1', '6']
# ['8', '4', '#']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 38 -----
# Seed: up
# ['3', '1', '#']
# ['8', '4', '6']
# ['5', '2', '7']
#
# Seed: down
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '2', '#']
#
# Seed: left
# ['3', '1', '6']
# ['8', '#', '4']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: down, Score: 46
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '2', '#']
#
# Seed: up, Score: 46
# ['3', '1', '#']
# ['8', '4', '6']
# ['5', '2', '7']
#
# --- Second best ---
# Seed: down, Score: 46
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '2', '#']
#
#
# ---- ST Selected ----
# Seed: up, Score: 46
# ['3', '1', '#']
# ['8', '4', '6']
# ['5', '2', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 39 -----
# Seed: down
# ['3', '1', '6']
# ['8', '4', '#']
# ['5', '2', '7']
#
# Seed: left
# ['3', '#', '1']
# ['8', '4', '6']
# ['5', '2', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 47
# ['3', '#', '1']
# ['8', '4', '6']
# ['5', '2', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: down, Score: 46
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '2', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 39 -----
# Seed: up
# ['3', '1', '6']
# ['8', '4', '#']
# ['5', '2', '7']
#
# Seed: left
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '#', '2']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 47
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '#', '2']
#
# --- Second best ---
# Seed: down, Score: 46
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '2', '#']
#
#
# ---- ST Selected ----
# Seed: left, Score: 47
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '#', '2']
#
# _______________________________________________
# ----- ST Calculated - Depth: 40 -----
# Seed: up
# ['3', '1', '6']
# ['8', '#', '7']
# ['5', '4', '2']
#
# Seed: right
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '2', '#']
#
# Seed: left
# ['3', '1', '6']
# ['8', '4', '7']
# ['#', '5', '2']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 48
# ['3', '1', '6']
# ['8', '4', '7']
# ['#', '5', '2']
#
# Seed: up, Score: 47
# ['3', '1', '6']
# ['8', '#', '7']
# ['5', '4', '2']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: down, Score: 46
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '2', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 39 -----
# Seed: up
# ['3', '1', '6']
# ['8', '4', '#']
# ['5', '2', '7']
#
# Seed: left
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '#', '2']
#
# --- Out of states---
# Getting from pending:
# Seed: left, Score: 48
# ['3', '1', '6']
# ['8', '4', '7']
# ['#', '5', '2']
#
# _______________________________________________
# ----- ST Calculated - Depth: 41 -----
# Seed: up
# ['3', '1', '6']
# ['#', '4', '7']
# ['8', '5', '2']
#
# Seed: right
# ['3', '1', '6']
# ['8', '4', '7']
# ['5', '#', '2']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 50
# ['3', '1', '6']
# ['#', '4', '7']
# ['8', '5', '2']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: left, Score: 46
# ['#', '8', '6']
# ['5', '3', '4']
# ['2', '1', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 39 -----
# Seed: down
# ['5', '8', '6']
# ['#', '3', '4']
# ['2', '1', '7']
#
# Seed: right
# ['8', '#', '6']
# ['5', '3', '4']
# ['2', '1', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: down, Score: 47
# ['5', '8', '6']
# ['#', '3', '4']
# ['2', '1', '7']
#
# --- Second best ---
# Seed: left, Score: 48
# ['3', '1', '6']
# ['8', '4', '7']
# ['#', '5', '2']
#
#
# ---- ST Selected ----
# Seed: down, Score: 47
# ['5', '8', '6']
# ['#', '3', '4']
# ['2', '1', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 40 -----
# Seed: up
# ['#', '8', '6']
# ['5', '3', '4']
# ['2', '1', '7']
#
# Seed: down
# ['5', '8', '6']
# ['2', '3', '4']
# ['#', '1', '7']
#
# Seed: right
# ['5', '8', '6']
# ['3', '#', '4']
# ['2', '1', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: down, Score: 48
# ['5', '8', '6']
# ['2', '3', '4']
# ['#', '1', '7']
#
# Seed: right, Score: 47
# ['5', '8', '6']
# ['3', '#', '4']
# ['2', '1', '7']
#
#
# ---- ST Selected ----
# Seed: right, Score: 47
# ['5', '8', '6']
# ['3', '#', '4']
# ['2', '1', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 41 -----
# Seed: up
# ['5', '#', '6']
# ['3', '8', '4']
# ['2', '1', '7']
#
# Seed: down
# ['5', '8', '6']
# ['3', '1', '4']
# ['2', '#', '7']
#
# Seed: right
# ['5', '8', '6']
# ['3', '4', '#']
# ['2', '1', '7']
#
# Seed: left
# ['5', '8', '6']
# ['#', '3', '4']
# ['2', '1', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 50
# ['5', '8', '6']
# ...
# ['6', '5', '3']
# ['8', '4', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 237
# ['1', '#', '2']
# ['6', '5', '3']
# ['8', '4', '7']
#
# --- Second best ---
# Seed: left, Score: 237
# ['1', '2', '3']
# ['#', '6', '7']
# ['8', '5', '4']
#
#
# ---- ST Selected ----
# Seed: left, Score: 237
# ['1', '#', '2']
# ['6', '5', '3']
# ['8', '4', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 230 -----
# Seed: down
# ['1', '5', '2']
# ['6', '#', '3']
# ['8', '4', '7']
#
# Seed: right
# ['1', '2', '#']
# ['6', '5', '3']
# ['8', '4', '7']
#
# Seed: left
# ['#', '1', '2']
# ['6', '5', '3']
# ['8', '4', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 239
# ['#', '1', '2']
# ['6', '5', '3']
# ['8', '4', '7']
#
# Seed: down, Score: 237
# ['1', '5', '2']
# ['6', '#', '3']
# ['8', '4', '7']
#
#
# ---- ST Selected ----
# Seed: down, Score: 237
# ['1', '5', '2']
# ['6', '#', '3']
# ['8', '4', '7']
#
# _______________________________________________
# ----- ST Calculated - Depth: 231 -----
# Seed: up
# ['1', '#', '2']
# ['6', '5', '3']
# ['8', '4', '7']
#
# Seed: down
# ['1', '5', '2']
# ['6', '4', '3']
# ['8', '#', '7']
#
# Seed: right
# ['1', '5', '2']
# ['6', '3', '#']
# ['8', '4', '7']
#
# Seed: left
# ['1', '5', '2']
# ['#', '6', '3']
# ['8', '4', '7']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 239
# ['1', '5', '2']
# ['#', '6', '3']
# ['8', '4', '7']
#
# Seed: right, Score: 239
# ['1', '5', '2']
# ['6', '3', '#']
# ['8', '4', '7']
#
# Seed: down, Score: 239
# ['1', '5', '2']
# ['6', '4', '3']
# ['8', '#', '7']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: left, Score: 237
# ['1', '2', '3']
# ['#', '6', '7']
# ['8', '5', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 232 -----
# Seed: up
# ['#', '2', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
# Seed: down
# ['1', '2', '3']
# ['8', '6', '7']
# ['#', '5', '4']
#
# Seed: right
# ['1', '2', '3']
# ['6', '#', '7']
# ['8', '5', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 239
# ['#', '2', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
# Seed: down, Score: 237
# ['1', '2', '3']
# ['8', '6', '7']
# ['#', '5', '4']
#
# --- Second best ---
# Seed: up, Score: 239
# ['#', '2', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
#
# ---- ST Selected ----
# Seed: down, Score: 237
# ['1', '2', '3']
# ['8', '6', '7']
# ['#', '5', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 233 -----
# Seed: up
# ['1', '2', '3']
# ['#', '6', '7']
# ['8', '5', '4']
#
# Seed: right
# ['1', '2', '3']
# ['8', '6', '7']
# ['5', '#', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 238
# ['1', '2', '3']
# ['8', '6', '7']
# ['5', '#', '4']
#
#
# ---- ST Selected ----
# Seed: right, Score: 238
# ['1', '2', '3']
# ['8', '6', '7']
# ['5', '#', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 234 -----
# Seed: up
# ['1', '2', '3']
# ['8', '#', '7']
# ['5', '6', '4']
#
# Seed: right
# ['1', '2', '3']
# ['8', '6', '7']
# ['5', '4', '#']
#
# Seed: left
# ['1', '2', '3']
# ['8', '6', '7']
# ['#', '5', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 239
# ['1', '2', '3']
# ['8', '6', '7']
# ['5', '4', '#']
#
# Seed: up, Score: 237
# ['1', '2', '3']
# ['8', '#', '7']
# ['5', '6', '4']
#
#
# ---- ST Selected ----
# Seed: up, Score: 237
# ['1', '2', '3']
# ['8', '#', '7']
# ['5', '6', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 235 -----
# Seed: up
# ['1', '#', '3']
# ['8', '2', '7']
# ['5', '6', '4']
#
# Seed: down
# ['1', '2', '3']
# ['8', '6', '7']
# ['5', '#', '4']
#
# Seed: right
# ['1', '2', '3']
# ['8', '7', '#']
# ['5', '6', '4']
#
# Seed: left
# ['1', '2', '3']
# ['#', '8', '7']
# ['5', '6', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 240
# ['1', '2', '3']
# ['#', '8', '7']
# ['5', '6', '4']
#
# Seed: up, Score: 240
# ['1', '#', '3']
# ['8', '2', '7']
# ['5', '6', '4']
#
# Seed: right, Score: 239
# ['1', '2', '3']
# ['8', '7', '#']
# ['5', '6', '4']
#
#
# ---- ST Selected ----
# Seed: right, Score: 239
# ['1', '2', '3']
# ['8', '7', '#']
# ['5', '6', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 236 -----
# Seed: up
# ['1', '2', '#']
# ['8', '7', '3']
# ['5', '6', '4']
#
# Seed: down
# ['1', '2', '3']
# ['8', '7', '4']
# ['5', '6', '#']
#
# Seed: left
# ['1', '2', '3']
# ['8', '#', '7']
# ['5', '6', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 241
# ['1', '2', '#']
# ['8', '7', '3']
# ['5', '6', '4']
#
# Seed: down, Score: 239
# ['1', '2', '3']
# ['8', '7', '4']
# ['5', '6', '#']
#
#
# ---- ST Selected ----
# Seed: down, Score: 239
# ['1', '2', '3']
# ['8', '7', '4']
# ['5', '6', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 237 -----
# Seed: up
# ['1', '2', '3']
# ['8', '7', '#']
# ['5', '6', '4']
#
# Seed: left
# ['1', '2', '3']
# ['8', '7', '4']
# ['5', '#', '6']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 241
# ['1', '2', '3']
# ['8', '7', '4']
# ['5', '#', '6']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: up, Score: 239
# ['#', '2', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 233 -----
# Seed: down
# ['1', '2', '3']
# ['#', '6', '7']
# ['8', '5', '4']
#
# Seed: right
# ['2', '#', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 241
# ['2', '#', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
# --- Second best ---
# Seed: up, Score: 241
# ['1', '2', '#']
# ['8', '7', '3']
# ['5', '6', '4']
#
#
# ---- ST Selected ----
# Seed: right, Score: 241
# ['2', '#', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 234 -----
# Seed: down
# ['2', '6', '3']
# ['1', '#', '7']
# ['8', '5', '4']
#
# Seed: right
# ['2', '3', '#']
# ['1', '6', '7']
# ['8', '5', '4']
#
# Seed: left
# ['#', '2', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 243
# ['2', '3', '#']
# ['1', '6', '7']
# ['8', '5', '4']
#
# Seed: down, Score: 241
# ['2', '6', '3']
# ['1', '#', '7']
# ['8', '5', '4']
#
#
# ---- ST Selected ----
# Seed: down, Score: 241
# ['2', '6', '3']
# ['1', '#', '7']
# ['8', '5', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 235 -----
# Seed: up
# ['2', '#', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
# Seed: down
# ['2', '6', '3']
# ['1', '5', '7']
# ['8', '#', '4']
#
# Seed: right
# ['2', '6', '3']
# ['1', '7', '#']
# ['8', '5', '4']
#
# Seed: left
# ['2', '6', '3']
# ['#', '1', '7']
# ['8', '5', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 243
# ['2', '6', '3']
# ['#', '1', '7']
# ['8', '5', '4']
#
# Seed: right, Score: 243
# ['2', '6', '3']
# ['1', '7', '#']
# ['8', '5', '4']
#
# Seed: down, Score: 243
# ['2', '6', '3']
# ['1', '5', '7']
# ['8', '#', '4']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: up, Score: 241
# ['1', '2', '#']
# ['8', '7', '3']
# ['5', '6', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 237 -----
# Seed: down
# ['1', '2', '3']
# ['8', '7', '#']
# ['5', '6', '4']
#
# Seed: left
# ['1', '#', '2']
# ['8', '7', '3']
# ['5', '6', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 243
# ['1', '#', '2']
# ['8', '7', '3']
# ['5', '6', '4']
#
# --- Second best ---
# Seed: right, Score: 243
# ['2', '6', '3']
# ['1', '7', '#']
# ['8', '5', '4']
#
#
# ---- ST Selected ----
# Seed: left, Score: 243
# ['1', '#', '2']
# ['8', '7', '3']
# ['5', '6', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 238 -----
# Seed: down
# ['1', '7', '2']
# ['8', '#', '3']
# ['5', '6', '4']
#
# Seed: right
# ['1', '2', '#']
# ['8', '7', '3']
# ['5', '6', '4']
#
# Seed: left
# ['#', '1', '2']
# ['8', '7', '3']
# ['5', '6', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 245
# ['#', '1', '2']
# ['8', '7', '3']
# ['5', '6', '4']
#
# Seed: down, Score: 243
# ['1', '7', '2']
# ['8', '#', '3']
# ['5', '6', '4']
#
#
# ---- ST Selected ----
# Seed: down, Score: 243
# ['1', '7', '2']
# ['8', '#', '3']
# ['5', '6', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 239 -----
# Seed: up
# ['1', '#', '2']
# ['8', '7', '3']
# ['5', '6', '4']
#
# Seed: down
# ['1', '7', '2']
# ['8', '6', '3']
# ['5', '#', '4']
#
# Seed: right
# ['1', '7', '2']
# ['8', '3', '#']
# ['5', '6', '4']
#
# Seed: left
# ['1', '7', '2']
# ['#', '8', '3']
# ['5', '6', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 246
# ['1', '7', '2']
# ['#', '8', '3']
# ['5', '6', '4']
#
# Seed: down, Score: 246
# ['1', '7', '2']
# ['8', '6', '3']
# ['5', '#', '4']
#
# Seed: right, Score: 245
# ['1', '7', '2']
# ['8', '3', '#']
# ['5', '6', '4']
#
# --- Not the best candidate. Selecting second best...
#
# ---- ST Selected ----
# Seed: right, Score: 243
# ['2', '6', '3']
# ['1', '7', '#']
# ['8', '5', '4']
#
# _______________________________________________
# ----- ST Calculated - Depth: 236 -----
# Seed: up
# ['2', '6', '#']
# ['1', '7', '3']
# ['8', '5', '4']
#
# Seed: down
# ['2', '6', '3']
# ['1', '7', '4']
# ['8', '5', '#']
#
# Seed: left
# ['2', '6', '3']
# ['1', '#', '7']
# ['8', '5', '4']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: up, Score: 245
# ['2', '6', '#']
# ['1', '7', '3']
# ['8', '5', '4']
#
# Seed: down, Score: 243
# ['2', '6', '3']
# ['1', '7', '4']
# ['8', '5', '#']
#
# --- Second best ---
# Seed: up, Score: 245
# ['2', '6', '#']
# ['1', '7', '3']
# ['8', '5', '4']
#
#
# ---- ST Selected ----
# Seed: down, Score: 243
# ['2', '6', '3']
# ['1', '7', '4']
# ['8', '5', '#']
#
# _______________________________________________
# ----- ST Calculated - Depth: 237 -----
# Seed: up
# ['2', '6', '3']
# ['1', '7', '#']
# ['8', '5', '4']
#
# Seed: left
# ['2', '6', '3']
# ['1', '7', '4']
# ['8', '#', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 243
# ['2', '6', '3']
# ['1', '7', '4']
# ['8', '#', '5']
#
#
# ---- ST Selected ----
# Seed: left, Score: 243
# ['2', '6', '3']
# ['1', '7', '4']
# ['8', '#', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 238 -----
# Seed: up
# ['2', '6', '3']
# ['1', '#', '4']
# ['8', '7', '5']
#
# Seed: right
# ['2', '6', '3']
# ['1', '7', '4']
# ['8', '5', '#']
#
# Seed: left
# ['2', '6', '3']
# ['1', '7', '4']
# ['#', '8', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: left, Score: 244
# ['2', '6', '3']
# ['1', '7', '4']
# ['#', '8', '5']
#
# Seed: up, Score: 243
# ['2', '6', '3']
# ['1', '#', '4']
# ['8', '7', '5']
#
#
# ---- ST Selected ----
# Seed: up, Score: 243
# ['2', '6', '3']
# ['1', '#', '4']
# ['8', '7', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 239 -----
# Seed: up
# ['2', '#', '3']
# ['1', '6', '4']
# ['8', '7', '5']
#
# Seed: down
# ['2', '6', '3']
# ['1', '7', '4']
# ['8', '#', '5']
#
# Seed: right
# ['2', '6', '3']
# ['1', '4', '#']
# ['8', '7', '5']
#
# Seed: left
# ['2', '6', '3']
# ['#', '1', '4']
# ['8', '7', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 246
# ['2', '6', '3']
# ['1', '4', '#']
# ['8', '7', '5']
#
# Seed: left, Score: 245
# ['2', '6', '3']
# ['#', '1', '4']
# ['8', '7', '5']
#
# Seed: up, Score: 245
# ['2', '#', '3']
# ['1', '6', '4']
# ['8', '7', '5']
#
#
# ---- ST Selected ----
# Seed: up, Score: 245
# ['2', '#', '3']
# ['1', '6', '4']
# ['8', '7', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 240 -----
# Seed: down
# ['2', '6', '3']
# ['1', '#', '4']
# ['8', '7', '5']
#
# Seed: right
# ['2', '3', '#']
# ['1', '6', '4']
# ['8', '7', '5']
#
# Seed: left
# ['#', '2', '3']
# ['1', '6', '4']
# ['8', '7', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 247
# ['2', '3', '#']
# ['1', '6', '4']
# ['8', '7', '5']
#
# Seed: left, Score: 245
# ['#', '2', '3']
# ['1', '6', '4']
# ['8', '7', '5']
#
#
# ---- ST Selected ----
# Seed: left, Score: 245
# ['#', '2', '3']
# ['1', '6', '4']
# ['8', '7', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 241 -----
# Seed: down
# ['1', '2', '3']
# ['#', '6', '4']
# ['8', '7', '5']
#
# Seed: right
# ['2', '#', '3']
# ['1', '6', '4']
# ['8', '7', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: down, Score: 245
# ['1', '2', '3']
# ['#', '6', '4']
# ['8', '7', '5']
#
#
# ---- ST Selected ----
# Seed: down, Score: 245
# ['1', '2', '3']
# ['#', '6', '4']
# ['8', '7', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 242 -----
# Seed: up
# ['#', '2', '3']
# ['1', '6', '4']
# ['8', '7', '5']
#
# Seed: down
# ['1', '2', '3']
# ['8', '6', '4']
# ['#', '7', '5']
#
# Seed: right
# ['1', '2', '3']
# ['6', '#', '4']
# ['8', '7', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 245
# ['1', '2', '3']
# ['6', '#', '4']
# ['8', '7', '5']
#
# Seed: down, Score: 245
# ['1', '2', '3']
# ['8', '6', '4']
# ['#', '7', '5']
#
#
# ---- ST Selected ----
# Seed: down, Score: 245
# ['1', '2', '3']
# ['8', '6', '4']
# ['#', '7', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 243 -----
# Seed: up
# ['1', '2', '3']
# ['#', '6', '4']
# ['8', '7', '5']
#
# Seed: right
# ['1', '2', '3']
# ['8', '6', '4']
# ['7', '#', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 245
# ['1', '2', '3']
# ['8', '6', '4']
# ['7', '#', '5']
#
#
# ---- ST Selected ----
# Seed: right, Score: 245
# ['1', '2', '3']
# ['8', '6', '4']
# ['7', '#', '5']
#
# _______________________________________________
# ----- ST Calculated - Depth: 244 -----
# Seed: up
# ['1', '2', '3']
# ['8', '#', '4']
# ['7', '6', '5']
#
# Seed: right
# ['1', '2', '3']
# ['8', '6', '4']
# ['7', '5', '#']
#
# Seed: left
# ['1', '2', '3']
# ['8', '6', '4']
# ['#', '7', '5']
#
# -----------------------------
#
# ---- ST Available ----
# Seed: right, Score: 247
# ['1', '2', '3']
# ['8', '6', '4']
# ['7', '5', '#']
#
# Seed: up, Score: 244
# ['1', '2', '3']
# ['8', '#', '4']
# ['7', '6', '5']
#
#
# ---- ST Selected ----
# Seed: up, Score: 244
# ['1', '2', '3']
# ['8', '#', '4']
# ['7', '6', '5']
#
# _______________________________________________
# ---Terminal---
# Depth: 244, Score: 244
# ['1', '2', '3']
# ['8', '#', '4']
# ['7', '6', '5']
#
# ---Algorithm---
# From:
# ['2', '1', '6']
# ['4', '#', '8']
# ['7', '5', '3']
#
#
# 1. down
# 2. right
# 3. up
# 4. left
# 5. down
# 6. left
# 7. up
# 8. right
# 9. down
# 10. right
# 11. up
# 12. left
# 13. down
# 14. left
# 15. up
# 16. right
# 17. down
# 18. right
# 19. up
# 20. left
# 21. left
# 22. up
# 23. right
# 24. down
# 25. left
# 26. down
# 27. right
# 28. up
# 29. left
# 30. up
# 31. right
# 32. down
# 33. left
# 34. down
# 35. right
# 36. up
# 37. up
# 38. left
# 39. down
# 40. right
# 41. down
# 42. left
# 43. up
# 44. up
# 45. right
# 46. down
# 47. left
# 48. down
# 49. right
# 50. up
# 51. left
# 52. up
# 53. right
# 54. down
# 55. right
# 56. up
# 57. left
# 58. down
# 59. right
# 60. up
# 61. left
# 62. down
# 63. right
# 64. down
# 65. left
# 66. up
# 67. right
# 68. up
# 69. left
# 70. down
# 71. right
# 72. down
# 73. left
# 74. up
# 75. left
# 76. up
# 77. right
# 78. right
# 79. down
# 80. down
# 81. left
# 82. up
# 83. up
# 84. right
# 85. down
# 86. left
# 87. down
# 88. left
# 89. up
# 90. right
# 91. right
# 92. up
# 93. left
# 94. down
# 95. right
# 96. up
# 97. left
# 98. down
# 99. down
# 100. left
# 101. up
# 102. right
# 103. right
# 104. down
# 105. left
# 106. up
# 107. left
# 108. down
# 109. right
# 110. up
# 111. right
# 112. up
# 113. left
# 114. down
# 115. right
# 116. up
# 117. left
# 118. left
# 119. down
# 120. right
# 121. up
# 122. right
# 123. down
# 124. left
# 125. left
# 126. up
# 127. right
# 128. down
# 129. right
# 130. down
# 131. left
# 132. up
# 133. right
# 134. up
# 135. left
# 136. down
# 137. left
# 138. down
# 139. right
# 140. up
# 141. up
# 142. left
# 143. down
# 144. right
# 145. down
# 146. left
# 147. up
# 148. up
# 149. right
# 150. down
# 151. left
# 152. down
# 153. right
# 154. up
# 155. left
# 156. up
# 157. right
# 158. down
# 159. right
# 160. down
# 161. left
# 162. up
# 163. left
# 164. down
# 165. right
# 166. up
# 167. right
# 168. up
# 169. left
# 170. down
# 171. right
# 172. down
# 173. left
# 174. up
# 175. left
# 176. down
# 177. right
# 178. up
# 179. left
# 180. down
# 181. right
# 182. up
# 183. right
# 184. down
# 185. left
# 186. up
# 187. right
# 188. down
# 189. left
# 190. up
# 191. up
# 192. right
# 193. down
# 194. left
# 195. down
# 196. left
# 197. up
# 198. right
# 199. down
# 200. right
# 201. up
# 202. left
# 203. down
# 204. right
# 205. up
# 206. left
# 207. up
# 208. right
# 209. down
# 210. left
# 211. down
# 212. left
# 213. up
# 214. right
# 215. right
# 216. up
# 217. left
# 218. down
# 219. left
# 220. up
# 221. right
# 222. down
# 223. down
# 224. left
# 225. up
# 226. right
# 227. right
# 228. down
# 229. left
# 230. up
# 231. left
# 232. up
# 233. right
# 234. down
# 235. right
# 236. down
# 237. left
# 238. up
# 239. up
# 240. left
# 241. down
# 242. down
# 243. right
# 244. up
# ---end---

# %%
if len(steps)==0:
      print('Not founded') 
else:
    
    #Si los pasos encontrados permiten llegar al estado marcado, entonces la solución es válida
    print('_____________________________')
    print('\nTesting solution...\n')
    i = 1
    for s in steps:
        test.move_value('#', s)
        if logs:
            print(f'{i}. Seed: {s}')
            print(format_state(test.grid_to_array()))
        i += 1
        
    if verify(test.grid_to_array(), t)==0:
        print('\n---Solution verified---')
    else:
        print('Invalid solution!')
# Out:
# _____________________________
#
# Testing solution...
#
# 1. Seed: down
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '#', '3']
#
# 2. Seed: right
# ['2', '1', '6']
# ['4', '5', '8']
# ['7', '3', '#']
#
# 3. Seed: up
# ['2', '1', '6']
# ['4', '5', '#']
# ['7', '3', '8']
#
# 4. Seed: left
# ['2', '1', '6']
# ['4', '#', '5']
# ['7', '3', '8']
#
# 5. Seed: down
# ['2', '1', '6']
# ['4', '3', '5']
# ['7', '#', '8']
#
# 6. Seed: left
# ['2', '1', '6']
# ['4', '3', '5']
# ['#', '7', '8']
#
# 7. Seed: up
# ['2', '1', '6']
# ['#', '3', '5']
# ['4', '7', '8']
#
# 8. Seed: right
# ['2', '1', '6']
# ['3', '#', '5']
# ['4', '7', '8']
#
# 9. Seed: down
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '#', '8']
#
# 10. Seed: right
# ['2', '1', '6']
# ['3', '7', '5']
# ['4', '8', '#']
#
# 11. Seed: up
# ['2', '1', '6']
# ['3', '7', '#']
# ['4', '8', '5']
#
# 12. Seed: left
# ['2', '1', '6']
# ['3', '#', '7']
# ['4', '8', '5']
#
# 13. Seed: down
# ['2', '1', '6']
# ['3', '8', '7']
# ['4', '#', '5']
#
# 14. Seed: left
# ['2', '1', '6']
# ['3', '8', '7']
# ['#', '4', '5']
#
# 15. Seed: up
# ['2', '1', '6']
# ['#', '8', '7']
# ['3', '4', '5']
#
# 16. Seed: right
# ['2', '1', '6']
# ['8', '#', '7']
# ['3', '4', '5']
#
# 17. Seed: down
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '#', '5']
#
# 18. Seed: right
# ['2', '1', '6']
# ['8', '4', '7']
# ['3', '5', '#']
#
# 19. Seed: up
# ['2', '1', '6']
# ['8', '4', '#']
# ['3', '5', '7']
#
# 20. Seed: left
# ['2', '1', '6']
# ['8', '#', '4']
# ['3', '5', '7']
#
# 21. Seed: left
# ['2', '1', '6']
# ['#', '8', '4']
# ['3', '5', '7']
#
# 22. Seed: up
# ['#', '1', '6']
# ['2', '8', '4']
# ['3', '5', '7']
#
# 23. Seed: right
# ['1', '#', '6']
# ['2', '8', '4']
# ['3', '5', '7']
#
# 24. Seed: down
# ['1', '8', '6']
# ['2', '#', '4']
# ['3', '5', '7']
#
# 25. Seed: left
# ['1', '8', '6']
# ['#', '2', '4']
# ['3', '5', '7']
#
# 26. Seed: down
# ['1', '8', '6']
# ['3', '2', '4']
# ['#', '5', '7']
#
# 27. Seed: right
# ['1', '8', '6']
# ['3', '2', '4']
# ['5', '#', '7']
#
# 28. Seed: up
# ['1', '8', '6']
# ['3', '#', '4']
# ['5', '2', '7']
#
# 29. Seed: left
# ['1', '8', '6']
# ['#', '3', '4']
# ['5', '2', '7']
#
# 30. Seed: up
# ['#', '8', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
# 31. Seed: right
# ['8', '#', '6']
# ['1', '3', '4']
# ['5', '2', '7']
#
# 32. Seed: down
# ['8', '3', '6']
# ['1', '#', '4']
# ['5', '2', '7']
#
# 33. Seed: left
# ['8', '3', '6']
# ['#', '1', '4']
# ['5', '2', '7']
#
# 34. Seed: down
# ['8', '3', '6']
# ['5', '1', '4']
# ['#', '2', '7']
#
# 35. Seed: right
# ['8', '3', '6']
# ['5', '1', '4']
# ['2', '#', '7']
#
# 36. Seed: up
# ['8', '3', '6']
# ['5', '#', '4']
# ['2', '1', '7']
#
# 37. Seed: up
# ['8', '#', '6']
# ['5', '3', '4']
# ['2', '1', '7']
#
# 38. Seed: left
# ['#', '8', '6']
# ['5', '3', '4']
# ['2', '1', '7']
#
# 39. Seed: down
# ['5', '8', '6']
# ['#', '3', '4']
# ['2', '1', '7']
#
# 40. Seed: right
# ['5', '8', '6']
# ['3', '#', '4']
# ['2', '1', '7']
#
# 41. Seed: down
# ['5', '8', '6']
# ['3', '1', '4']
# ['2', '#', '7']
#
# 42. Seed: left
# ['5', '8', '6']
# ['3', '1', '4']
# ['#', '2', '7']
#
# 43. Seed: up
# ['5', '8', '6']
# ['#', '1', '4']
# ['3', '2', '7']
#
# 44. Seed: up
# ['#', '8', '6']
# ['5', '1', '4']
# ['3', '2', '7']
#
# 45. Seed: right
# ['8', '#', '6']
# ['5', '1', '4']
# ['3', '2', '7']
#
# 46. Seed: down
# ['8', '1', '6']
# ['5', '#', '4']
# ['3', '2', '7']
#
# 47. Seed: left
# ['8', '1', '6']
# ['#', '5', '4']
# ['3', '2', '7']
#
# 48. Seed: down
# ['8', '1', '6']
# ['3', '5', '4']
# ['#', '2', '7']
#
# 49. Seed: right
# ['8', '1', '6']
# ['3', '5', '4']
# ['2', '#', '7']
#
# 50. Seed: up
# ['8', '1', '6']
# ['3', '#', '4']
# ['2', '5', '7']
#
# 51. Seed: left
# ['8', '1', '6']
# ['#', '3', '4']
# ['2', '5', '7']
#
# 52. Seed: up
# ['#', '1', '6']
# ['8', '3', '4']
# ['2', '5', '7']
#
# 53. Seed: right
# ['1', '#', '6']
# ['8', '3', '4']
# ['2', '5', '7']
#
# 54. Seed: down
# ['1', '3', '6']
# ['8', '#', '4']
# ['2', '5', '7']
#
# 55. Seed: right
# ['1', '3', '6']
# ['8', '4', '#']
# ['2', '5', '7']
#
# 56. Seed: up
# ['1', '3', '#']
# ['8', '4', '6']
# ['2', '5', '7']
#
# 57. Seed: left
# ['1', '#', '3']
# ['8', '4', '6']
# ['2', '5', '7']
#
# 58. Seed: down
# ['1', '4', '3']
# ['8', '#', '6']
# ['2', '5', '7']
#
# 59. Seed: right
# ['1', '4', '3']
# ['8', '6', '#']
# ['2', '5', '7']
#
# 60. Seed: up
# ['1', '4', '#']
# ['8', '6', '3']
# ['2', '5', '7']
#
# 61. Seed: left
# ['1', '#', '4']
# ['8', '6', '3']
# ['2', '5', '7']
#
# 62. Seed: down
# ['1', '6', '4']
# ['8', '#', '3']
# ['2', '5', '7']
#
# 63. Seed: right
# ['1', '6', '4']
# ['8', '3', '#']
# ['2', '5', '7']
#
# 64. Seed: down
# ['1', '6', '4']
# ['8', '3', '7']
# ['2', '5', '#']
#
# 65. Seed: left
# ['1', '6', '4']
# ['8', '3', '7']
# ['2', '#', '5']
#
# 66. Seed: up
# ['1', '6', '4']
# ['8', '#', '7']
# ['2', '3', '5']
#
# 67. Seed: right
# ['1', '6', '4']
# ['8', '7', '#']
# ['2', '3', '5']
#
# 68. Seed: up
# ['1', '6', '#']
# ['8', '7', '4']
# ['2', '3', '5']
#
# 69. Seed: left
# ['1', '#', '6']
# ['8', '7', '4']
# ['2', '3', '5']
#
# 70. Seed: down
# ['1', '7', '6']
# ['8', '#', '4']
# ['2', '3', '5']
#
# 71. Seed: right
# ['1', '7', '6']
# ['8', '4', '#']
# ['2', '3', '5']
#
# 72. Seed: down
# ['1', '7', '6']
# ['8', '4', '5']
# ['2', '3', '#']
#
# 73. Seed: left
# ['1', '7', '6']
# ['8', '4', '5']
# ['2', '#', '3']
#
# 74. Seed: up
# ['1', '7', '6']
# ['8', '#', '5']
# ['2', '4', '3']
#
# 75. Seed: left
# ['1', '7', '6']
# ['#', '8', '5']
# ['2', '4', '3']
#
# 76. Seed: up
# ['#', '7', '6']
# ['1', '8', '5']
# ['2', '4', '3']
#
# 77. Seed: right
# ['7', '#', '6']
# ['1', '8', '5']
# ['2', '4', '3']
#
# 78. Seed: right
# ['7', '6', '#']
# ['1', '8', '5']
# ['2', '4', '3']
#
# 79. Seed: down
# ['7', '6', '5']
# ['1', '8', '#']
# ['2', '4', '3']
#
# 80. Seed: down
# ['7', '6', '5']
# ['1', '8', '3']
# ['2', '4', '#']
#
# 81. Seed: left
# ['7', '6', '5']
# ['1', '8', '3']
# ['2', '#', '4']
#
# 82. Seed: up
# ['7', '6', '5']
# ['1', '#', '3']
# ['2', '8', '4']
#
# 83. Seed: up
# ['7', '#', '5']
# ['1', '6', '3']
# ['2', '8', '4']
#
# 84. Seed: right
# ['7', '5', '#']
# ['1', '6', '3']
# ['2', '8', '4']
#
# 85. Seed: down
# ['7', '5', '3']
# ['1', '6', '#']
# ['2', '8', '4']
#
# 86. Seed: left
# ['7', '5', '3']
# ['1', '#', '6']
# ['2', '8', '4']
#
# 87. Seed: down
# ['7', '5', '3']
# ['1', '8', '6']
# ['2', '#', '4']
#
# 88. Seed: left
# ['7', '5', '3']
# ['1', '8', '6']
# ['#', '2', '4']
#
# 89. Seed: up
# ['7', '5', '3']
# ['#', '8', '6']
# ['1', '2', '4']
#
# 90. Seed: right
# ['7', '5', '3']
# ['8', '#', '6']
# ['1', '2', '4']
#
# 91. Seed: right
# ['7', '5', '3']
# ['8', '6', '#']
# ['1', '2', '4']
#
# 92. Seed: up
# ['7', '5', '#']
# ['8', '6', '3']
# ['1', '2', '4']
#
# 93. Seed: left
# ['7', '#', '5']
# ['8', '6', '3']
# ['1', '2', '4']
#
# 94. Seed: down
# ['7', '6', '5']
# ['8', '#', '3']
# ['1', '2', '4']
#
# 95. Seed: right
# ['7', '6', '5']
# ['8', '3', '#']
# ['1', '2', '4']
#
# 96. Seed: up
# ['7', '6', '#']
# ['8', '3', '5']
# ['1', '2', '4']
#
# 97. Seed: left
# ['7', '#', '6']
# ['8', '3', '5']
# ['1', '2', '4']
#
# 98. Seed: down
# ['7', '3', '6']
# ['8', '#', '5']
# ['1', '2', '4']
#
# 99. Seed: down
# ['7', '3', '6']
# ['8', '2', '5']
# ['1', '#', '4']
#
# 100. Seed: left
# ['7', '3', '6']
# ['8', '2', '5']
# ['#', '1', '4']
#
# 101. Seed: up
# ['7', '3', '6']
# ['#', '2', '5']
# ['8', '1', '4']
#
# 102. Seed: right
# ['7', '3', '6']
# ['2', '#', '5']
# ['8', '1', '4']
#
# 103. Seed: right
# ['7', '3', '6']
# ['2', '5', '#']
# ['8', '1', '4']
#
# 104. Seed: down
# ['7', '3', '6']
# ['2', '5', '4']
# ['8', '1', '#']
#
# 105. Seed: left
# ['7', '3', '6']
# ['2', '5', '4']
# ['8', '#', '1']
#
# 106. Seed: up
# ['7', '3', '6']
# ['2', '#', '4']
# ['8', '5', '1']
#
# 107. Seed: left
# ['7', '3', '6']
# ['#', '2', '4']
# ['8', '5', '1']
#
# 108. Seed: down
# ['7', '3', '6']
# ['8', '2', '4']
# ['#', '5', '1']
#
# 109. Seed: right
# ['7', '3', '6']
# ['8', '2', '4']
# ['5', '#', '1']
#
# 110. Seed: up
# ['7', '3', '6']
# ['8', '#', '4']
# ['5', '2', '1']
#
# 111. Seed: right
# ['7', '3', '6']
# ['8', '4', '#']
# ['5', '2', '1']
#
# 112. Seed: up
# ['7', '3', '#']
# ['8', '4', '6']
# ['5', '2', '1']
#
# 113. Seed: left
# ['7', '#', '3']
# ['8', '4', '6']
# ['5', '2', '1']
#
# 114. Seed: down
# ['7', '4', '3']
# ['8', '#', '6']
# ['5', '2', '1']
#
# 115. Seed: right
# ['7', '4', '3']
# ['8', '6', '#']
# ['5', '2', '1']
#
# 116. Seed: up
# ['7', '4', '#']
# ['8', '6', '3']
# ['5', '2', '1']
#
# 117. Seed: left
# ['7', '#', '4']
# ['8', '6', '3']
# ['5', '2', '1']
#
# 118. Seed: left
# ['#', '7', '4']
# ['8', '6', '3']
# ['5', '2', '1']
#
# 119. Seed: down
# ['8', '7', '4']
# ['#', '6', '3']
# ['5', '2', '1']
#
# 120. Seed: right
# ['8', '7', '4']
# ['6', '#', '3']
# ['5', '2', '1']
#
# 121. Seed: up
# ['8', '#', '4']
# ['6', '7', '3']
# ['5', '2', '1']
#
# 122. Seed: right
# ['8', '4', '#']
# ['6', '7', '3']
# ['5', '2', '1']
#
# 123. Seed: down
# ['8', '4', '3']
# ['6', '7', '#']
# ['5', '2', '1']
#
# 124. Seed: left
# ['8', '4', '3']
# ['6', '#', '7']
# ['5', '2', '1']
#
# 125. Seed: left
# ['8', '4', '3']
# ['#', '6', '7']
# ['5', '2', '1']
#
# 126. Seed: up
# ['#', '4', '3']
# ['8', '6', '7']
# ['5', '2', '1']
#
# 127. Seed: right
# ['4', '#', '3']
# ['8', '6', '7']
# ['5', '2', '1']
#
# 128. Seed: down
# ['4', '6', '3']
# ['8', '#', '7']
# ['5', '2', '1']
#
# 129. Seed: right
# ['4', '6', '3']
# ['8', '7', '#']
# ['5', '2', '1']
#
# 130. Seed: down
# ['4', '6', '3']
# ['8', '7', '1']
# ['5', '2', '#']
#
# 131. Seed: left
# ['4', '6', '3']
# ['8', '7', '1']
# ['5', '#', '2']
#
# 132. Seed: up
# ['4', '6', '3']
# ['8', '#', '1']
# ['5', '7', '2']
#
# 133. Seed: right
# ['4', '6', '3']
# ['8', '1', '#']
# ['5', '7', '2']
#
# 134. Seed: up
# ['4', '6', '#']
# ['8', '1', '3']
# ['5', '7', '2']
#
# 135. Seed: left
# ['4', '#', '6']
# ['8', '1', '3']
# ['5', '7', '2']
#
# 136. Seed: down
# ['4', '1', '6']
# ['8', '#', '3']
# ['5', '7', '2']
#
# 137. Seed: left
# ['4', '1', '6']
# ['#', '8', '3']
# ['5', '7', '2']
#
# 138. Seed: down
# ['4', '1', '6']
# ['5', '8', '3']
# ['#', '7', '2']
#
# 139. Seed: right
# ['4', '1', '6']
# ['5', '8', '3']
# ['7', '#', '2']
#
# 140. Seed: up
# ['4', '1', '6']
# ['5', '#', '3']
# ['7', '8', '2']
#
# 141. Seed: up
# ['4', '#', '6']
# ['5', '1', '3']
# ['7', '8', '2']
#
# 142. Seed: left
# ['#', '4', '6']
# ['5', '1', '3']
# ['7', '8', '2']
#
# 143. Seed: down
# ['5', '4', '6']
# ['#', '1', '3']
# ['7', '8', '2']
#
# 144. Seed: right
# ['5', '4', '6']
# ['1', '#', '3']
# ['7', '8', '2']
#
# 145. Seed: down
# ['5', '4', '6']
# ['1', '8', '3']
# ['7', '#', '2']
#
# 146. Seed: left
# ['5', '4', '6']
# ['1', '8', '3']
# ['#', '7', '2']
#
# 147. Seed: up
# ['5', '4', '6']
# ['#', '8', '3']
# ['1', '7', '2']
#
# 148. Seed: up
# ['#', '4', '6']
# ['5', '8', '3']
# ['1', '7', '2']
#
# 149. Seed: right
# ['4', '#', '6']
# ['5', '8', '3']
# ['1', '7', '2']
#
# 150. Seed: down
# ['4', '8', '6']
# ['5', '#', '3']
# ['1', '7', '2']
#
# 151. Seed: left
# ['4', '8', '6']
# ['#', '5', '3']
# ['1', '7', '2']
#
# 152. Seed: down
# ['4', '8', '6']
# ['1', '5', '3']
# ['#', '7', '2']
#
# 153. Seed: right
# ['4', '8', '6']
# ['1', '5', '3']
# ['7', '#', '2']
#
# 154. Seed: up
# ['4', '8', '6']
# ['1', '#', '3']
# ['7', '5', '2']
#
# 155. Seed: left
# ['4', '8', '6']
# ['#', '1', '3']
# ['7', '5', '2']
#
# 156. Seed: up
# ['#', '8', '6']
# ['4', '1', '3']
# ['7', '5', '2']
#
# 157. Seed: right
# ['8', '#', '6']
# ['4', '1', '3']
# ['7', '5', '2']
#
# 158. Seed: down
# ['8', '1', '6']
# ['4', '#', '3']
# ['7', '5', '2']
#
# 159. Seed: right
# ['8', '1', '6']
# ['4', '3', '#']
# ['7', '5', '2']
#
# 160. Seed: down
# ['8', '1', '6']
# ['4', '3', '2']
# ['7', '5', '#']
#
# 161. Seed: left
# ['8', '1', '6']
# ['4', '3', '2']
# ['7', '#', '5']
#
# 162. Seed: up
# ['8', '1', '6']
# ['4', '#', '2']
# ['7', '3', '5']
#
# 163. Seed: left
# ['8', '1', '6']
# ['#', '4', '2']
# ['7', '3', '5']
#
# 164. Seed: down
# ['8', '1', '6']
# ['7', '4', '2']
# ['#', '3', '5']
#
# 165. Seed: right
# ['8', '1', '6']
# ['7', '4', '2']
# ['3', '#', '5']
#
# 166. Seed: up
# ['8', '1', '6']
# ['7', '#', '2']
# ['3', '4', '5']
#
# 167. Seed: right
# ['8', '1', '6']
# ['7', '2', '#']
# ['3', '4', '5']
#
# 168. Seed: up
# ['8', '1', '#']
# ['7', '2', '6']
# ['3', '4', '5']
#
# 169. Seed: left
# ['8', '#', '1']
# ['7', '2', '6']
# ['3', '4', '5']
#
# 170. Seed: down
# ['8', '2', '1']
# ['7', '#', '6']
# ['3', '4', '5']
#
# 171. Seed: right
# ['8', '2', '1']
# ['7', '6', '#']
# ['3', '4', '5']
#
# 172. Seed: down
# ['8', '2', '1']
# ['7', '6', '5']
# ['3', '4', '#']
#
# 173. Seed: left
# ['8', '2', '1']
# ['7', '6', '5']
# ['3', '#', '4']
#
# 174. Seed: up
# ['8', '2', '1']
# ['7', '#', '5']
# ['3', '6', '4']
#
# 175. Seed: left
# ['8', '2', '1']
# ['#', '7', '5']
# ['3', '6', '4']
#
# 176. Seed: down
# ['8', '2', '1']
# ['3', '7', '5']
# ['#', '6', '4']
#
# 177. Seed: right
# ['8', '2', '1']
# ['3', '7', '5']
# ['6', '#', '4']
#
# 178. Seed: up
# ['8', '2', '1']
# ['3', '#', '5']
# ['6', '7', '4']
#
# 179. Seed: left
# ['8', '2', '1']
# ['#', '3', '5']
# ['6', '7', '4']
#
# 180. Seed: down
# ['8', '2', '1']
# ['6', '3', '5']
# ['#', '7', '4']
#
# 181. Seed: right
# ['8', '2', '1']
# ['6', '3', '5']
# ['7', '#', '4']
#
# 182. Seed: up
# ['8', '2', '1']
# ['6', '#', '5']
# ['7', '3', '4']
#
# 183. Seed: right
# ['8', '2', '1']
# ['6', '5', '#']
# ['7', '3', '4']
#
# 184. Seed: down
# ['8', '2', '1']
# ['6', '5', '4']
# ['7', '3', '#']
#
# 185. Seed: left
# ['8', '2', '1']
# ['6', '5', '4']
# ['7', '#', '3']
#
# 186. Seed: up
# ['8', '2', '1']
# ['6', '#', '4']
# ['7', '5', '3']
#
# 187. Seed: right
# ['8', '2', '1']
# ['6', '4', '#']
# ['7', '5', '3']
#
# 188. Seed: down
# ['8', '2', '1']
# ['6', '4', '3']
# ['7', '5', '#']
#
# 189. Seed: left
# ['8', '2', '1']
# ['6', '4', '3']
# ['7', '#', '5']
#
# 190. Seed: up
# ['8', '2', '1']
# ['6', '#', '3']
# ['7', '4', '5']
#
# 191. Seed: up
# ['8', '#', '1']
# ['6', '2', '3']
# ['7', '4', '5']
#
# 192. Seed: right
# ['8', '1', '#']
# ['6', '2', '3']
# ['7', '4', '5']
#
# 193. Seed: down
# ['8', '1', '3']
# ['6', '2', '#']
# ['7', '4', '5']
#
# 194. Seed: left
# ['8', '1', '3']
# ['6', '#', '2']
# ['7', '4', '5']
#
# 195. Seed: down
# ['8', '1', '3']
# ['6', '4', '2']
# ['7', '#', '5']
#
# 196. Seed: left
# ['8', '1', '3']
# ['6', '4', '2']
# ['#', '7', '5']
#
# 197. Seed: up
# ['8', '1', '3']
# ['#', '4', '2']
# ['6', '7', '5']
#
# 198. Seed: right
# ['8', '1', '3']
# ['4', '#', '2']
# ['6', '7', '5']
#
# 199. Seed: down
# ['8', '1', '3']
# ['4', '7', '2']
# ['6', '#', '5']
#
# 200. Seed: right
# ['8', '1', '3']
# ['4', '7', '2']
# ['6', '5', '#']
#
# 201. Seed: up
# ['8', '1', '3']
# ['4', '7', '#']
# ['6', '5', '2']
#
# 202. Seed: left
# ['8', '1', '3']
# ['4', '#', '7']
# ['6', '5', '2']
#
# 203. Seed: down
# ['8', '1', '3']
# ['4', '5', '7']
# ['6', '#', '2']
#
# 204. Seed: right
# ['8', '1', '3']
# ['4', '5', '7']
# ['6', '2', '#']
#
# 205. Seed: up
# ['8', '1', '3']
# ['4', '5', '#']
# ['6', '2', '7']
#
# 206. Seed: left
# ['8', '1', '3']
# ['4', '#', '5']
# ['6', '2', '7']
#
# 207. Seed: up
# ['8', '#', '3']
# ['4', '1', '5']
# ['6', '2', '7']
#
# 208. Seed: right
# ['8', '3', '#']
# ['4', '1', '5']
# ['6', '2', '7']
#
# 209. Seed: down
# ['8', '3', '5']
# ['4', '1', '#']
# ['6', '2', '7']
#
# 210. Seed: left
# ['8', '3', '5']
# ['4', '#', '1']
# ['6', '2', '7']
#
# 211. Seed: down
# ['8', '3', '5']
# ['4', '2', '1']
# ['6', '#', '7']
#
# 212. Seed: left
# ['8', '3', '5']
# ['4', '2', '1']
# ['#', '6', '7']
#
# 213. Seed: up
# ['8', '3', '5']
# ['#', '2', '1']
# ['4', '6', '7']
#
# 214. Seed: right
# ['8', '3', '5']
# ['2', '#', '1']
# ['4', '6', '7']
#
# 215. Seed: right
# ['8', '3', '5']
# ['2', '1', '#']
# ['4', '6', '7']
#
# 216. Seed: up
# ['8', '3', '#']
# ['2', '1', '5']
# ['4', '6', '7']
#
# 217. Seed: left
# ['8', '#', '3']
# ['2', '1', '5']
# ['4', '6', '7']
#
# 218. Seed: down
# ['8', '1', '3']
# ['2', '#', '5']
# ['4', '6', '7']
#
# 219. Seed: left
# ['8', '1', '3']
# ['#', '2', '5']
# ['4', '6', '7']
#
# 220. Seed: up
# ['#', '1', '3']
# ['8', '2', '5']
# ['4', '6', '7']
#
# 221. Seed: right
# ['1', '#', '3']
# ['8', '2', '5']
# ['4', '6', '7']
#
# 222. Seed: down
# ['1', '2', '3']
# ['8', '#', '5']
# ['4', '6', '7']
#
# 223. Seed: down
# ['1', '2', '3']
# ['8', '6', '5']
# ['4', '#', '7']
#
# 224. Seed: left
# ['1', '2', '3']
# ['8', '6', '5']
# ['#', '4', '7']
#
# 225. Seed: up
# ['1', '2', '3']
# ['#', '6', '5']
# ['8', '4', '7']
#
# 226. Seed: right
# ['1', '2', '3']
# ['6', '#', '5']
# ['8', '4', '7']
#
# 227. Seed: right
# ['1', '2', '3']
# ['6', '5', '#']
# ['8', '4', '7']
#
# 228. Seed: down
# ['1', '2', '3']
# ['6', '5', '7']
# ['8', '4', '#']
#
# 229. Seed: left
# ['1', '2', '3']
# ['6', '5', '7']
# ['8', '#', '4']
#
# 230. Seed: up
# ['1', '2', '3']
# ['6', '#', '7']
# ['8', '5', '4']
#
# 231. Seed: left
# ['1', '2', '3']
# ['#', '6', '7']
# ['8', '5', '4']
#
# 232. Seed: up
# ['#', '2', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
# 233. Seed: right
# ['2', '#', '3']
# ['1', '6', '7']
# ['8', '5', '4']
#
# 234. Seed: down
# ['2', '6', '3']
# ['1', '#', '7']
# ['8', '5', '4']
#
# 235. Seed: right
# ['2', '6', '3']
# ['1', '7', '#']
# ['8', '5', '4']
#
# 236. Seed: down
# ['2', '6', '3']
# ['1', '7', '4']
# ['8', '5', '#']
#
# 237. Seed: left
# ['2', '6', '3']
# ['1', '7', '4']
# ['8', '#', '5']
#
# 238. Seed: up
# ['2', '6', '3']
# ['1', '#', '4']
# ['8', '7', '5']
#
# 239. Seed: up
# ['2', '#', '3']
# ['1', '6', '4']
# ['8', '7', '5']
#
# 240. Seed: left
# ['#', '2', '3']
# ['1', '6', '4']
# ['8', '7', '5']
#
# 241. Seed: down
# ['1', '2', '3']
# ['#', '6', '4']
# ['8', '7', '5']
#
# 242. Seed: down
# ['1', '2', '3']
# ['8', '6', '4']
# ['#', '7', '5']
#
# 243. Seed: right
# ['1', '2', '3']
# ['8', '6', '4']
# ['7', '#', '5']
#
# 244. Seed: up
# ['1', '2', '3']
# ['8', '#', '4']
# ['7', '6', '5']
#
#
# ---Solution verified---
